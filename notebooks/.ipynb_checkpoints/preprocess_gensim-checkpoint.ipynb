# %% [markdown]
# ## imports

# %%
#importing packages
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns

import re
import string

# nltk
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem.porter import *
from nltk.stem import WordNetLemmatizer

# sklearn
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# gensim
from gensim.models import Word2Vec

from collections import defaultdict

# %matplotlib inline

# %% [markdown]
# ## Data process
# train data: https://www.kaggle.com/arkhoshghalb/twitter-sentiment-analysis-hatred-speech

# %%
train = pd.read_csv('../data/train.csv', encoding = "ISO-8859-1", engine='python')
test = pd.read_csv('../data/test.csv', encoding = "ISO-8859-1", engine='python')
train
# test
# Out:
#           id  label                                              tweet
# 0          1      0   @user when a father is dysfunctional and is s...
# 1          2      0  @user @user thanks for #lyft credit i can't us...
# 2          3      0                                bihday your majesty
# 3          4      0  #model   i love u take with u all the time in ...
# 4          5      0             factsguide: society now    #motivation
# ...      ...    ...                                                ...
# 31957  31958      0  ate @user isz that youuu?Ã°ÂÂÂÃ°ÂÂÂÃ°ÂÂ...
# 31958  31959      0    to see nina turner on the airwaves trying to...
# 31959  31960      0  listening to sad songs on a monday morning otw...
# 31960  31961      1  @user #sikh #temple vandalised in in #calgary,...
# 31961  31962      0                   thank you @user for you follow
#
# [31962 rows x 3 columns]

# %%
#putting train and test together
combi = train.append(test, ignore_index=True)

# %%
sentences = combi['tweet'].tolist()
sentences_ss = " ".join(sentences)

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(sentences_ss)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ## clean tweet text

# %%
combi['cleanTweet'] = combi['tweet']
combi.head()
# Out:
#    id  label                                              tweet  \
# 0   1    0.0   @user when a father is dysfunctional and is s...
# 1   2    0.0  @user @user thanks for #lyft credit i can't us...
# 2   3    0.0                                bihday your majesty
# 3   4    0.0  #model   i love u take with u all the time in ...
# 4   5    0.0             factsguide: society now    #motivation
#
#                                           cleanTweet
# 0   @user when a father is dysfunctional and is s...
# 1  @user @user thanks for #lyft credit i can't us...
# 2                                bihday your majesty
# 3  #model   i love u take with u all the time in ...
# 4             factsguide: society now    #motivation

# %%
combi['cleanTweet'] = combi['tweet'].map(lambda x: re.sub('@\S+', ' ', x))
combi.head()
# Out:
#    id  label                                              tweet  \
# 0   1    0.0   @user when a father is dysfunctional and is s...
# 1   2    0.0  @user @user thanks for #lyft credit i can't us...
# 2   3    0.0                                bihday your majesty
# 3   4    0.0  #model   i love u take with u all the time in ...
# 4   5    0.0             factsguide: society now    #motivation
#
#                                           cleanTweet
# 0     when a father is dysfunctional and is so se...
# 1      thanks for #lyft credit i can't use cause ...
# 2                                bihday your majesty
# 3  #model   i love u take with u all the time in ...
# 4             factsguide: society now    #motivation

# %%
#upper case to lower case
combi['cleanTweet'] = combi['cleanTweet'].map(lambda x: x.lower())
#remove number
combi['cleanTweet'] = combi['cleanTweet'].map(lambda x: re.sub(r'\d+', '', x))
#remove punctuation
combi['cleanTweet'] = combi['cleanTweet'].map(lambda x: x.translate(x.maketrans('', '', string.punctuation)))
#remove whitespace
combi['cleanTweet'] = combi['cleanTweet'].map(lambda x: x.strip())
#remove url
url_cleaner = "https?:\S+|http?:\S|[^A-Za-z0-9]+"
combi['cleanTweet'] = combi['cleanTweet'].map(lambda x: re.sub(url_cleaner, ' ', x))
#removing small words
combi['cleanTweet'] = combi['cleanTweet'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
# Replace 3 or more consecutive letters by 2 letter.
combi['cleanTweet'] = combi['cleanTweet'].map(lambda x: re.sub(r"(.)\1\1+", r"\1\1", x))
combi
# Out:
#           id  label                                              tweet  \
# 0          1    0.0   @user when a father is dysfunctional and is s...
# 1          2    0.0  @user @user thanks for #lyft credit i can't us...
# 2          3    0.0                                bihday your majesty
# 3          4    0.0  #model   i love u take with u all the time in ...
# 4          5    0.0             factsguide: society now    #motivation
# ...      ...    ...                                                ...
# 49154  49155    NaN  thought factory: left-right polarisation! #tru...
# 49155  49156    NaN  feeling like a mermaid Ã°ÂÂÂ #hairflip #nev...
# 49156  49157    NaN  #hillary #campaigned today in #ohio((omg)) &am...
# 49157  49158    NaN  happy, at work conference: right mindset leads...
# 49158  49159    NaN  my   song "so glad" free download!  #shoegaze ...
#
#                                               cleanTweet
# 0      when father dysfunctional selfish drags kids i...
# 1      thanks lyft credit cant cause they dont offer ...
# 2                                    bihday your majesty
# 3                              model love take with time
# 4                          factsguide society motivation
# ...                                                  ...
# 49154  thought factory leftright polarisation trump u...
# 49155  feeling like mermaid hairflip neverready forma...
# 49156  hillary campaigned today ohioomg used words li...
# 49157  happy work conference right mindset leads cult...
# 49158  song glad free download shoegaze newmusic newsong
#
# [49159 rows x 4 columns]

# %%
#Tokenization
tokenized_tweet = combi['cleanTweet'].apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# 0    [when, father, dysfunctional, selfish, drags, ...
# 1    [thanks, lyft, credit, cant, cause, they, dont...
# 2                              [bihday, your, majesty]
# 3                      [model, love, take, with, time]
# 4                    [factsguide, society, motivation]
# Name: cleanTweet, dtype: object

# %%
# Removing Consecutive letters
words_with_consecutive_letters = ['little', 'called', 'better', 'common', 'cannot', 'matter', 'middle',
 'follow', 'choose', 'letter', 'killed', 'summer', 'battle', 'supply', 'bottom', 'passed', 'button',
 'manner', 'happen', 'speech', 'troops', 'filled', 'latter', 'yellow', 'dinner', 'coffee', 'fellow', 'tissue',
 'hidden', 'smooth', 'pulled', 'narrow', 'lesson', 'missed', 'cattle', 'winner', 'bigger', 'valley', 'dollar',
 'suffer', 'mirror', 'passes', 'losses', 'terror', 'cotton', 'summit', 'cheese', 'bottle', 'freely', 'vessel',
 'sheets', 'sudden', 'copper', 'fallen', 'differ', 'gotten', 'buffer', 'banner', 'ball',
 'been', 'beer', 'beet', 'beep', 'bell', 'boom', 'boot', 'book', 'bull', 'butt', 'call', 'cell', 'coon',
 'dell', 'doll', 'door', 'doom', 'fall', 'fell', 'feel', 'feet', 'foot', 'food', 'fool', 'fuss',
 'full', 'gull', 'gall', 'hall', 'hell', 'heed', 'heel', 'hill', 'hull', 'all', 'add', 'bee', 'boo',
 'ell', 'ebb', 'egg', 'fee', 'goo', 'too', 'tee', 'see', 'Hollywood', 'bookkeeping', 'aloofness',
 'foolishness', 'woodcutter', 'bulletproof', 'bootlegging', 'bittersweet', 'schoolfellow', 'committee',
 'wheelbarrow', 'boorishness', 'bookkeeper', 'beerbelly', 'look', 'tomorrow', 'will', 'school', 'weekend']

tokenized_tweet = tokenized_tweet.apply(lambda text: [word if word in words_with_consecutive_letters else re.sub(r"(.)\1+", r"\1", word) for word in text])
tokenized_tweet.head()
# Out:
# 0    [when, father, dysfunctional, selfish, drags, ...
# 1    [thanks, lyft, credit, cant, cause, they, dont...
# 2                              [bihday, your, majesty]
# 3                      [model, love, take, with, time]
# 4                    [factsguide, society, motivation]
# Name: cleanTweet, dtype: object

# %%
# Removing stop words
stop_words = set(stopwords.words('english'))
tokenized_tweet = tokenized_tweet.apply(lambda text: [word for word in text if word not in stop_words])
tokenized_tweet.head()
# Out:
# 0    [father, dysfunctional, selfish, drags, kids, ...
# 1    [thanks, lyft, credit, cant, cause, dont, ofer...
# 2                                    [bihday, majesty]
# 3                            [model, love, take, time]
# 4                    [factsguide, society, motivation]
# Name: cleanTweet, dtype: object

# %%
# stemming
stemmer = PorterStemmer()
tokenized_tweet = tokenized_tweet.apply(lambda x: [stemmer.stem(i) for i in x])
tokenized_tweet.head()
# Out:
# 0     [father, dysfunct, selfish, drag, kid, dysfunct]
# 1    [thank, lyft, credit, cant, caus, dont, ofer, ...
# 2                                    [bihday, majesti]
# 3                            [model, love, take, time]
# 4                          [factsguid, societi, motiv]
# Name: cleanTweet, dtype: object

# %%
# Lemmatizing the words using WordNet
lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV}
def lemmatize_words(text):
    pos_tagged_text = nltk.pos_tag(text)
    # pos_tagged_text = text.apply(lambda x: nltk.pos_tag(x))
    return [lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_tagged_text]

tokenized_tweet = tokenized_tweet.apply(lambda text: lemmatize_words(text))
tokenized_tweet.head()
# Out:
# 0     [father, dysfunct, selfish, drag, kid, dysfunct]
# 1    [thank, lyft, credit, cant, caus, dont, ofer, ...
# 2                                    [bihday, majesti]
# 3                            [model, love, take, time]
# 4                          [factsguid, societi, motiv]
# Name: cleanTweet, dtype: object

# %%
for i in range(len(tokenized_tweet)):
    tokenized_tweet[i] = ' '.join(tokenized_tweet[i])
combi['cleanTweet'] = tokenized_tweet
combi
# Out:
#           id  label                                              tweet  \
# 0          1    0.0   @user when a father is dysfunctional and is s...
# 1          2    0.0  @user @user thanks for #lyft credit i can't us...
# 2          3    0.0                                bihday your majesty
# 3          4    0.0  #model   i love u take with u all the time in ...
# 4          5    0.0             factsguide: society now    #motivation
# ...      ...    ...                                                ...
# 49154  49155    NaN  thought factory: left-right polarisation! #tru...
# 49155  49156    NaN  feeling like a mermaid Ã°ÂÂÂ #hairflip #nev...
# 49156  49157    NaN  #hillary #campaigned today in #ohio((omg)) &am...
# 49157  49158    NaN  happy, at work conference: right mindset leads...
# 49158  49159    NaN  my   song "so glad" free download!  #shoegaze ...
#
#                                               cleanTweet
# 0              father dysfunct selfish drag kid dysfunct
# 1      thank lyft credit cant caus dont ofer whelchai...
# 2                                         bihday majesti
# 3                                   model love take time
# 4                                factsguid societi motiv
# ...                                                  ...
# 49154  think factori leftright polaris trump uselect ...
# 49155  fele like mermaid hairflip nevereadi formal we...
# 49156  hilari campaign today ohiomg use word like ase...
# 49157  hapi work confer right mindset lead cultureofd...
# 49158      song glad fre download shoegaz newmus newsong
#
# [49159 rows x 4 columns]

# %%
all_words = ' '.join([text for text in combi['cleanTweet']])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# Importing the built-in logging module
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# Creating the model and setting values for the various parameters
num_features = 400  # Word vector dimensionality
min_word_count = 1 # Minimum word count
num_workers = 6     # Number of parallel threads
context = 10       # Context window size
downsampling = 1e-3 # (0.001) Downsample setting for frequent words

tokenized_tweet = combi['cleanTweet'].apply(lambda x: x.split())

# print("Training model....")
w2v_model = Word2Vec(sentences=tokenized_tweet,workers=num_workers,min_count=min_word_count,window=context,sample=downsampling)
# model.build_vocab(data['cleanTweet'])
# Out:
# 2021-02-04 21:44:14,800 : INFO : collecting all words and their counts
# 2021-02-04 21:44:14,801 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-02-04 21:44:14,815 : INFO : PROGRESS: at sentence #10000, processed 66722 words, keeping 14498 word types
# 2021-02-04 21:44:14,829 : INFO : PROGRESS: at sentence #20000, processed 132681 words, keeping 22779 word types
# 2021-02-04 21:44:14,843 : INFO : PROGRESS: at sentence #30000, processed 198922 words, keeping 29708 word types
# 2021-02-04 21:44:14,857 : INFO : PROGRESS: at sentence #40000, processed 264796 words, keeping 36033 word types
# 2021-02-04 21:44:14,870 : INFO : collected 41206 word types from a corpus of 325639 raw words and 49159 sentences
# 2021-02-04 21:44:14,871 : INFO : Loading a fresh vocabulary
# 2021-02-04 21:44:15,048 : INFO : effective_min_count=1 retains 41206 unique words (100% of original 41206, drops 0)
# 2021-02-04 21:44:15,048 : INFO : effective_min_count=1 leaves 325639 word corpus (100% of original 325639, drops 0)
# 2021-02-04 21:44:15,140 : INFO : deleting the raw counts dictionary of 41206 items
# 2021-02-04 21:44:15,141 : INFO : sample=0.001 downsamples 34 most-common words
# 2021-02-04 21:44:15,141 : INFO : downsampling leaves estimated 311758 word corpus (95.7% of prior 325639)
# 2021-02-04 21:44:15,198 : INFO : estimated required memory for 41206 words and 100 dimensions: 53567800 bytes
# 2021-02-04 21:44:15,198 : INFO : resetting layer weights
# 2021-02-04 21:44:21,034 : INFO : training model with 6 workers on 41206 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2021-02-04 21:44:21,250 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:21,253 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:21,254 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:21,255 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:21,259 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:21,260 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:21,260 : INFO : EPOCH - 1 : training on 325639 raw words (311799 effective words) took 0.2s, 1421351 effective words/s
# 2021-02-04 21:44:21,482 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:21,488 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:21,490 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:21,492 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:21,494 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:21,496 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:21,496 : INFO : EPOCH - 2 : training on 325639 raw words (311855 effective words) took 0.2s, 1360905 effective words/s
# 2021-02-04 21:44:21,709 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:21,709 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:21,713 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:21,719 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:21,721 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:21,723 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:21,723 : INFO : EPOCH - 3 : training on 325639 raw words (311584 effective words) took 0.2s, 1414680 effective words/s
# 2021-02-04 21:44:21,924 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:21,933 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:21,947 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:21,948 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:21,948 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:21,953 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:21,953 : INFO : EPOCH - 4 : training on 325639 raw words (311674 effective words) took 0.2s, 1395645 effective words/s
# 2021-02-04 21:44:22,159 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:22,161 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:22,163 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:22,166 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:22,168 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:22,169 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:22,170 : INFO : EPOCH - 5 : training on 325639 raw words (311818 effective words) took 0.2s, 1485413 effective words/s
# 2021-02-04 21:44:22,170 : INFO : training on a 1628195 raw words (1558730 effective words) took 1.1s, 1372508 effective words/s

# %%
w2v_model.train(combi['cleanTweet'], total_examples=w2v_model.corpus_count, epochs=60)

# To make the model memory efficient
w2v_model.init_sims(replace=False)

# Saving the model for later use. Can be loaded using Word2Vec.load()
model_name = "word2vec"
w2v_model.save(model_name)
# Out:
# 2021-02-04 21:44:22,174 : WARNING : Effective 'alpha' higher than previous training cycles
# 2021-02-04 21:44:22,174 : INFO : training model with 6 workers on 41206 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2021-02-04 21:44:22,527 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:22,527 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:22,528 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:22,530 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:22,530 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:22,531 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:22,531 : INFO : EPOCH - 1 : training on 2117250 raw words (597005 effective words) took 0.4s, 1688837 effective words/s
# 2021-02-04 21:44:22,886 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:22,886 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:22,887 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:22,888 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:22,888 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:22,889 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:22,889 : INFO : EPOCH - 2 : training on 2117250 raw words (597005 effective words) took 0.4s, 1686479 effective words/s
# 2021-02-04 21:44:23,244 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:23,244 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:23,245 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:23,246 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:23,246 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:23,248 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:23,248 : INFO : EPOCH - 3 : training on 2117250 raw words (597005 effective words) took 0.4s, 1679196 effective words/s
# 2021-02-04 21:44:23,631 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:23,632 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:23,632 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:23,634 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:23,635 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:23,636 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:23,637 : INFO : EPOCH - 4 : training on 2117250 raw words (597005 effective words) took 0.4s, 1551584 effective words/s
# 2021-02-04 21:44:23,990 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:23,992 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:23,993 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:23,994 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:23,994 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:23,995 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:23,995 : INFO : EPOCH - 5 : training on 2117250 raw words (597005 effective words) took 0.4s, 1681869 effective words/s
# 2021-02-04 21:44:24,340 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:24,341 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:24,341 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:24,342 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:24,343 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:24,344 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:24,344 : INFO : EPOCH - 6 : training on 2117250 raw words (597005 effective words) took 0.3s, 1727378 effective words/s
# 2021-02-04 21:44:24,692 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:24,693 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:24,693 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:24,694 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:24,695 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:24,696 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:24,696 : INFO : EPOCH - 7 : training on 2117250 raw words (597005 effective words) took 0.3s, 1713733 effective words/s
# 2021-02-04 21:44:25,056 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:25,059 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:25,059 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:25,060 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:25,060 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:25,061 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:25,061 : INFO : EPOCH - 8 : training on 2117250 raw words (597005 effective words) took 0.4s, 1649625 effective words/s
# 2021-02-04 21:44:25,414 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:25,415 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:25,416 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:25,417 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:25,418 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:25,418 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:25,418 : INFO : EPOCH - 9 : training on 2117250 raw words (597005 effective words) took 0.4s, 1686927 effective words/s
# 2021-02-04 21:44:25,772 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:25,773 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:25,773 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:25,774 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:25,775 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:25,776 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:25,776 : INFO : EPOCH - 10 : training on 2117250 raw words (597005 effective words) took 0.4s, 1684825 effective words/s
# 2021-02-04 21:44:26,133 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:26,135 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:26,135 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:26,138 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:26,138 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:26,139 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:26,139 : INFO : EPOCH - 11 : training on 2117250 raw words (597005 effective words) took 0.4s, 1661548 effective words/s
# 2021-02-04 21:44:26,484 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:26,487 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:26,488 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:26,488 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:26,489 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:26,490 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:26,490 : INFO : EPOCH - 12 : training on 2117250 raw words (597005 effective words) took 0.3s, 1716818 effective words/s
# 2021-02-04 21:44:26,858 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:26,858 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:26,860 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:26,860 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:26,861 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:26,862 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:26,862 : INFO : EPOCH - 13 : training on 2117250 raw words (597005 effective words) took 0.4s, 1619848 effective words/s
# 2021-02-04 21:44:27,262 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:27,264 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:27,264 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:27,266 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:27,267 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:27,267 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:27,268 : INFO : EPOCH - 14 : training on 2117250 raw words (597005 effective words) took 0.4s, 1488040 effective words/s
# 2021-02-04 21:44:27,659 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:27,660 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:27,661 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:27,661 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:27,662 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:27,663 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:27,663 : INFO : EPOCH - 15 : training on 2117250 raw words (597005 effective words) took 0.4s, 1533444 effective words/s
# 2021-02-04 21:44:28,010 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:28,011 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:28,012 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:28,012 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:28,014 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:28,014 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:28,015 : INFO : EPOCH - 16 : training on 2117250 raw words (597005 effective words) took 0.3s, 1713309 effective words/s
# 2021-02-04 21:44:28,370 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:28,372 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:28,372 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:28,374 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:28,375 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:28,375 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:28,375 : INFO : EPOCH - 17 : training on 2117250 raw words (597005 effective words) took 0.4s, 1670108 effective words/s
# 2021-02-04 21:44:28,724 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:28,725 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:28,726 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:28,728 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:28,729 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:28,730 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:28,730 : INFO : EPOCH - 18 : training on 2117250 raw words (597005 effective words) took 0.4s, 1701268 effective words/s
# 2021-02-04 21:44:29,147 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:29,148 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:29,149 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:29,150 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:29,153 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:29,153 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:29,154 : INFO : EPOCH - 19 : training on 2117250 raw words (597005 effective words) took 0.4s, 1425022 effective words/s
# 2021-02-04 21:44:29,619 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:29,626 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:29,631 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:29,632 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:29,633 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:29,634 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:29,634 : INFO : EPOCH - 20 : training on 2117250 raw words (597005 effective words) took 0.5s, 1253703 effective words/s
# 2021-02-04 21:44:30,050 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:30,054 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:30,056 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:30,058 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:30,058 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:30,059 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:30,060 : INFO : EPOCH - 21 : training on 2117250 raw words (597005 effective words) took 0.4s, 1428314 effective words/s
# 2021-02-04 21:44:30,449 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:30,450 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:30,450 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:30,453 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:30,454 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:30,454 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:30,455 : INFO : EPOCH - 22 : training on 2117250 raw words (597005 effective words) took 0.4s, 1531589 effective words/s
# 2021-02-04 21:44:30,839 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:30,839 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:30,840 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:30,841 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:30,842 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:30,843 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:30,843 : INFO : EPOCH - 23 : training on 2117250 raw words (597005 effective words) took 0.4s, 1549720 effective words/s
# 2021-02-04 21:44:31,230 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:31,230 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:31,232 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:31,232 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:31,233 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:31,234 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:31,234 : INFO : EPOCH - 24 : training on 2117250 raw words (597005 effective words) took 0.4s, 1540802 effective words/s
# 2021-02-04 21:44:31,599 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:31,600 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:31,600 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:31,601 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:31,601 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:31,603 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:31,604 : INFO : EPOCH - 25 : training on 2117250 raw words (597005 effective words) took 0.4s, 1632582 effective words/s
# 2021-02-04 21:44:31,966 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:31,967 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:31,968 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:31,970 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:31,971 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:31,972 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:31,972 : INFO : EPOCH - 26 : training on 2117250 raw words (597005 effective words) took 0.4s, 1634576 effective words/s
# 2021-02-04 21:44:32,333 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:32,333 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:32,334 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:32,335 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:32,337 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:32,337 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:32,338 : INFO : EPOCH - 27 : training on 2117250 raw words (597005 effective words) took 0.4s, 1649069 effective words/s
# 2021-02-04 21:44:32,698 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:32,699 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:32,701 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:32,701 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:32,702 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:32,703 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:32,703 : INFO : EPOCH - 28 : training on 2117250 raw words (597005 effective words) took 0.4s, 1650461 effective words/s
# 2021-02-04 21:44:33,081 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:33,082 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:33,083 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:33,084 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:33,085 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:33,085 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:33,086 : INFO : EPOCH - 29 : training on 2117250 raw words (597005 effective words) took 0.4s, 1574679 effective words/s
# 2021-02-04 21:44:33,443 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:33,445 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:33,446 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:33,447 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:33,448 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:33,448 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:33,449 : INFO : EPOCH - 30 : training on 2117250 raw words (597005 effective words) took 0.4s, 1660176 effective words/s
# 2021-02-04 21:44:33,807 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:33,809 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:33,810 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:33,812 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:33,812 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:33,813 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:33,813 : INFO : EPOCH - 31 : training on 2117250 raw words (597005 effective words) took 0.4s, 1653564 effective words/s
# 2021-02-04 21:44:34,169 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:34,170 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:34,170 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:34,171 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:34,172 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:34,173 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:34,174 : INFO : EPOCH - 32 : training on 2117250 raw words (597005 effective words) took 0.4s, 1672033 effective words/s
# 2021-02-04 21:44:34,530 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:34,531 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:34,532 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:34,533 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:34,534 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:34,534 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:34,535 : INFO : EPOCH - 33 : training on 2117250 raw words (597005 effective words) took 0.4s, 1669583 effective words/s
# 2021-02-04 21:44:34,898 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:34,899 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:34,900 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:34,902 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:34,902 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:34,903 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:34,903 : INFO : EPOCH - 34 : training on 2117250 raw words (597005 effective words) took 0.4s, 1637343 effective words/s
# 2021-02-04 21:44:35,267 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:35,270 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:35,271 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:35,272 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:35,273 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:35,273 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:35,274 : INFO : EPOCH - 35 : training on 2117250 raw words (597005 effective words) took 0.4s, 1634025 effective words/s
# 2021-02-04 21:44:35,641 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:35,642 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:35,644 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:35,645 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:35,645 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:35,645 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:35,646 : INFO : EPOCH - 36 : training on 2117250 raw words (597005 effective words) took 0.4s, 1620045 effective words/s
# 2021-02-04 21:44:36,018 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:36,018 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:36,019 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:36,021 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:36,021 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:36,023 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:36,023 : INFO : EPOCH - 37 : training on 2117250 raw words (597005 effective words) took 0.4s, 1600180 effective words/s
# 2021-02-04 21:44:36,386 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:36,388 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:36,389 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:36,389 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:36,390 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:36,391 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:36,391 : INFO : EPOCH - 38 : training on 2117250 raw words (597005 effective words) took 0.4s, 1638472 effective words/s
# 2021-02-04 21:44:36,769 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:36,770 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:36,771 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:36,773 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:36,774 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:36,774 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:36,774 : INFO : EPOCH - 39 : training on 2117250 raw words (597005 effective words) took 0.4s, 1597786 effective words/s
# 2021-02-04 21:44:37,135 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:37,136 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:37,137 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:37,139 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:37,140 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:37,140 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:37,141 : INFO : EPOCH - 40 : training on 2117250 raw words (597005 effective words) took 0.4s, 1646461 effective words/s
# 2021-02-04 21:44:37,501 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:37,502 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:37,503 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:37,504 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:37,505 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:37,505 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:37,506 : INFO : EPOCH - 41 : training on 2117250 raw words (597005 effective words) took 0.4s, 1650597 effective words/s
# 2021-02-04 21:44:37,869 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:37,871 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:37,872 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:37,874 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:37,874 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:37,875 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:37,876 : INFO : EPOCH - 42 : training on 2117250 raw words (597005 effective words) took 0.4s, 1628799 effective words/s
# 2021-02-04 21:44:38,267 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:38,270 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:38,272 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:38,273 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:38,273 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:38,274 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:38,274 : INFO : EPOCH - 43 : training on 2117250 raw words (597005 effective words) took 0.4s, 1515191 effective words/s
# 2021-02-04 21:44:38,637 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:38,638 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:38,639 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:38,639 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:38,640 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:38,641 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:38,641 : INFO : EPOCH - 44 : training on 2117250 raw words (597005 effective words) took 0.4s, 1643083 effective words/s
# 2021-02-04 21:44:39,008 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:39,010 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:39,010 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:39,011 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:39,012 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:39,013 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:39,013 : INFO : EPOCH - 45 : training on 2117250 raw words (597005 effective words) took 0.4s, 1618278 effective words/s
# 2021-02-04 21:44:39,384 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:39,385 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:39,385 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:39,386 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:39,387 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:39,388 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:39,388 : INFO : EPOCH - 46 : training on 2117250 raw words (597005 effective words) took 0.4s, 1607888 effective words/s
# 2021-02-04 21:44:39,770 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:39,770 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:39,771 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:39,772 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:39,772 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:39,773 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:39,773 : INFO : EPOCH - 47 : training on 2117250 raw words (597005 effective words) took 0.4s, 1564983 effective words/s
# 2021-02-04 21:44:40,128 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:40,130 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:40,130 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:40,132 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:40,132 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:40,134 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:40,134 : INFO : EPOCH - 48 : training on 2117250 raw words (597005 effective words) took 0.4s, 1666931 effective words/s
# 2021-02-04 21:44:40,491 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:40,492 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:40,493 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:40,495 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:40,496 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:40,496 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:40,497 : INFO : EPOCH - 49 : training on 2117250 raw words (597005 effective words) took 0.4s, 1661413 effective words/s
# 2021-02-04 21:44:40,850 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:40,853 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:40,854 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:40,854 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:40,855 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:40,856 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:40,856 : INFO : EPOCH - 50 : training on 2117250 raw words (597005 effective words) took 0.4s, 1678616 effective words/s
# 2021-02-04 21:44:41,212 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:41,213 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:41,214 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:41,215 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:41,215 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:41,216 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:41,217 : INFO : EPOCH - 51 : training on 2117250 raw words (597005 effective words) took 0.4s, 1670655 effective words/s
# 2021-02-04 21:44:41,577 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:41,579 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:41,580 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:41,581 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:41,581 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:41,583 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:41,583 : INFO : EPOCH - 52 : training on 2117250 raw words (597005 effective words) took 0.4s, 1645728 effective words/s
# 2021-02-04 21:44:41,946 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:41,947 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:41,948 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:41,949 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:41,949 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:41,950 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:41,950 : INFO : EPOCH - 53 : training on 2117250 raw words (597005 effective words) took 0.4s, 1641352 effective words/s
# 2021-02-04 21:44:42,298 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:42,299 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:42,300 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:42,301 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:42,302 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:42,302 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:42,303 : INFO : EPOCH - 54 : training on 2117250 raw words (597005 effective words) took 0.3s, 1708795 effective words/s
# 2021-02-04 21:44:42,659 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:42,660 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:42,661 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:42,661 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:42,662 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:42,663 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:42,663 : INFO : EPOCH - 55 : training on 2117250 raw words (597005 effective words) took 0.4s, 1672469 effective words/s
# 2021-02-04 21:44:43,011 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:43,011 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:43,012 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:43,012 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:43,013 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:43,014 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:43,014 : INFO : EPOCH - 56 : training on 2117250 raw words (597005 effective words) took 0.3s, 1714186 effective words/s
# 2021-02-04 21:44:43,369 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:43,371 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:43,372 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:43,373 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:43,373 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:43,374 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:43,375 : INFO : EPOCH - 57 : training on 2117250 raw words (597005 effective words) took 0.4s, 1671678 effective words/s
# 2021-02-04 21:44:43,723 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:43,725 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:43,726 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:43,726 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:43,727 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:43,729 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:43,729 : INFO : EPOCH - 58 : training on 2117250 raw words (597005 effective words) took 0.4s, 1701978 effective words/s
# 2021-02-04 21:44:44,085 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:44,085 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:44,086 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:44,086 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:44,087 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:44,088 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:44,088 : INFO : EPOCH - 59 : training on 2117250 raw words (597005 effective words) took 0.4s, 1681306 effective words/s
# 2021-02-04 21:44:44,453 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-02-04 21:44:44,454 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-02-04 21:44:44,454 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-02-04 21:44:44,455 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-04 21:44:44,456 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-04 21:44:44,458 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-04 21:44:44,459 : INFO : EPOCH - 60 : training on 2117250 raw words (597005 effective words) took 0.4s, 1624819 effective words/s
# 2021-02-04 21:44:44,459 : INFO : training on a 127035000 raw words (35820300 effective words) took 22.3s, 1607435 effective words/s
# 2021-02-04 21:44:44,459 : INFO : precomputing L2-norms of word weight vectors
# 2021-02-04 21:44:44,466 : INFO : saving Word2Vec object under word2vec, separately None
# 2021-02-04 21:44:44,467 : INFO : not storing attribute vectors_norm
# 2021-02-04 21:44:44,467 : INFO : not storing attribute cum_table
# 2021-02-04 21:44:44,693 : INFO : saved word2vec

# %%
def display_pca_scatterplot(model, words=None, sample=0):
    if words == None:
        if sample > 0:
            words = np.random.choice(list(model.vocab.keys()), sample)
        else:
            words = [ word for word in model.vocab ]

    word_vectors = np.array([model[w] for w in words])

    twodim = PCA().fit_transform(word_vectors)[:,:2]

    plt.figure(figsize=(6,6))
    plt.scatter(twodim[:,0], twodim[:,1], edgecolors='k', c='r')
    for word, (x,y) in zip(words, twodim):
        plt.text(x+0.05, y+0.05, word)
    plt.savefig('./plot.png')

# %% [markdown]
# ## Test word2vec

# %%
w2v_model.wv.most_similar("father")
# Out:
# [('fathersday', 0.9928107261657715),
#  ('papa', 0.9920880794525146),
#  ('dad', 0.9913462400436401),
#  ('dadi', 0.9773353338241577),
#  ('daygod', 0.9767324328422546),
#  ('fatherday', 0.9724577069282532),
#  ('lopezchiro', 0.9723654985427856),
#  ('felizdiadelpadr', 0.9694415330886841),
#  ('jan', 0.962023138999939),
#  ('shinpad', 0.9615089893341064)]

# %%
w2v_model.wv.vocab
# Out:
# {'father': <gensim.models.keyedvectors.Vocab at 0x7fef5b186350>,
#  'dysfunct': <gensim.models.keyedvectors.Vocab at 0x7fef5ab05610>,
#  'selfish': <gensim.models.keyedvectors.Vocab at 0x7fef5ea5e890>,
#  'drag': <gensim.models.keyedvectors.Vocab at 0x7fef5b4539d0>,
#  'kid': <gensim.models.keyedvectors.Vocab at 0x7fef303242d0>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x7fef30324090>,
#  'lyft': <gensim.models.keyedvectors.Vocab at 0x7fef30324390>,
#  'credit': <gensim.models.keyedvectors.Vocab at 0x7fef30324310>,
#  'cant': <gensim.models.keyedvectors.Vocab at 0x7fef30324150>,
#  'caus': <gensim.models.keyedvectors.Vocab at 0x7fef30324350>,
#  'dont': <gensim.models.keyedvectors.Vocab at 0x7fef30324290>,
#  'ofer': <gensim.models.keyedvectors.Vocab at 0x7fef303240d0>,
#  'whelchair': <gensim.models.keyedvectors.Vocab at 0x7fef30324210>,
#  'van': <gensim.models.keyedvectors.Vocab at 0x7fef303241d0>,
#  'disapoint': <gensim.models.keyedvectors.Vocab at 0x7fef30324050>,
#  'gethank': <gensim.models.keyedvectors.Vocab at 0x7fef388c7050>,
#  'bihday': <gensim.models.keyedvectors.Vocab at 0x7fef388c7090>,
#  'majesti': <gensim.models.keyedvectors.Vocab at 0x7fef388c70d0>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x7fef388c7110>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7fef388c7150>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7fef388c7190>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7fef388c71d0>,
#  'factsguid': <gensim.models.keyedvectors.Vocab at 0x7fef388c7210>,
#  'societi': <gensim.models.keyedvectors.Vocab at 0x7fef388c7250>,
#  'motiv': <gensim.models.keyedvectors.Vocab at 0x7fef388c7290>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x7fef388c72d0>,
#  'fare': <gensim.models.keyedvectors.Vocab at 0x7fef388c7310>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x7fef388c7350>,
#  'leav': <gensim.models.keyedvectors.Vocab at 0x7fef388c7390>,
#  'chao': <gensim.models.keyedvectors.Vocab at 0x7fef388c73d0>,
#  'disput': <gensim.models.keyedvectors.Vocab at 0x7fef388c7410>,
#  'alshowandnogo': <gensim.models.keyedvectors.Vocab at 0x7fef388c7450>,
#  'camp': <gensim.models.keyedvectors.Vocab at 0x7fef388c7490>,
#  'tomorrow': <gensim.models.keyedvectors.Vocab at 0x7fef388c74d0>,
#  'dani': <gensim.models.keyedvectors.Vocab at 0x7fef388c7510>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7fef388c7550>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7fef388c7590>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7fef388c75d0>,
#  'exam': <gensim.models.keyedvectors.Vocab at 0x7fef388c7610>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7fef388c7650>,
#  'hate': <gensim.models.keyedvectors.Vocab at 0x7fef388c7690>,
#  'imagin': <gensim.models.keyedvectors.Vocab at 0x7fef388c76d0>,
#  'actorslif': <gensim.models.keyedvectors.Vocab at 0x7fef388c7710>,
#  'revolutionschol': <gensim.models.keyedvectors.Vocab at 0x7fef388c7750>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x7fef388c7790>,
#  'land': <gensim.models.keyedvectors.Vocab at 0x7fef388c77d0>,
#  'alin': <gensim.models.keyedvectors.Vocab at 0x7fef388c7810>,
#  'cav': <gensim.models.keyedvectors.Vocab at 0x7fef388c7850>,
#  'champion': <gensim.models.keyedvectors.Vocab at 0x7fef388c7890>,
#  'cleveland': <gensim.models.keyedvectors.Vocab at 0x7fef388c78d0>,
#  'clevelandcavali': <gensim.models.keyedvectors.Vocab at 0x7fef388c7910>,
#  'welcom': <gensim.models.keyedvectors.Vocab at 0x7fef388c7950>,
#  'ireland': <gensim.models.keyedvectors.Vocab at 0x7fef388c7990>,
#  'consum': <gensim.models.keyedvectors.Vocab at 0x7fef388c79d0>,
#  'price': <gensim.models.keyedvectors.Vocab at 0x7fef388c7a10>,
#  'index': <gensim.models.keyedvectors.Vocab at 0x7fef388c7a50>,
#  'climb': <gensim.models.keyedvectors.Vocab at 0x7fef388c7a90>,
#  'previou': <gensim.models.keyedvectors.Vocab at 0x7fef388c7ad0>,
#  'blog': <gensim.models.keyedvectors.Vocab at 0x7fef388c7b10>,
#  'silver': <gensim.models.keyedvectors.Vocab at 0x7fef388c7b50>,
#  'gold': <gensim.models.keyedvectors.Vocab at 0x7fef388c7b90>,
#  'forex': <gensim.models.keyedvectors.Vocab at 0x7fef388c7bd0>,
#  'orlando': <gensim.models.keyedvectors.Vocab at 0x7fef388c7c10>,
#  'standwithorlando': <gensim.models.keyedvectors.Vocab at 0x7fef388c7c50>,
#  'pulseshot': <gensim.models.keyedvectors.Vocab at 0x7fef388c7c90>,
#  'orlandoshot': <gensim.models.keyedvectors.Vocab at 0x7fef388c7cd0>,
#  'bigerproblem': <gensim.models.keyedvectors.Vocab at 0x7fef388c7d10>,
#  'heabreak': <gensim.models.keyedvectors.Vocab at 0x7fef388c7d50>,
#  'valu': <gensim.models.keyedvectors.Vocab at 0x7fef388c7d90>,
#  'dadi': <gensim.models.keyedvectors.Vocab at 0x7fef388c7dd0>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7fef388c7e10>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7fef388c7e50>,
#  'getingf': <gensim.models.keyedvectors.Vocab at 0x7fef388c7e90>,
#  'cal': <gensim.models.keyedvectors.Vocab at 0x7fef388c7ed0>,
#  'michigan': <gensim.models.keyedvectors.Vocab at 0x7fef388c7f10>,
#  'middl': <gensim.models.keyedvectors.Vocab at 0x7fef388c7f50>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x7fef388c7f90>,
#  'wal': <gensim.models.keyedvectors.Vocab at 0x7fef388c7fd0>,
#  'chant': <gensim.models.keyedvectors.Vocab at 0x7fef3031c050>,
#  'tcot': <gensim.models.keyedvectors.Vocab at 0x7fef3031c090>,
#  'coment': <gensim.models.keyedvectors.Vocab at 0x7fef3031c0d0>,
#  'australia': <gensim.models.keyedvectors.Vocab at 0x7fef3031c110>,
#  'opkilingbay': <gensim.models.keyedvectors.Vocab at 0x7fef3031c150>,
#  'seashepherd': <gensim.models.keyedvectors.Vocab at 0x7fef3031c190>,
#  'helpcovedolphin': <gensim.models.keyedvectors.Vocab at 0x7fef3031c1d0>,
#  'thecov': <gensim.models.keyedvectors.Vocab at 0x7fef3031c210>,
#  'ouchjunior': <gensim.models.keyedvectors.Vocab at 0x7fef3031c250>,
#  'angri': <gensim.models.keyedvectors.Vocab at 0x7fef3031c290>,
#  'junior': <gensim.models.keyedvectors.Vocab at 0x7fef3031c2d0>,
#  'yugyoem': <gensim.models.keyedvectors.Vocab at 0x7fef3031c310>,
#  'paner': <gensim.models.keyedvectors.Vocab at 0x7fef3031c350>,
#  'posit': <gensim.models.keyedvectors.Vocab at 0x7fef3031c390>,
#  'retwet': <gensim.models.keyedvectors.Vocab at 0x7fef3031c3d0>,
#  'agr': <gensim.models.keyedvectors.Vocab at 0x7fef3031c410>,
#  'friday': <gensim.models.keyedvectors.Vocab at 0x7fef3031c450>,
#  'smile': <gensim.models.keyedvectors.Vocab at 0x7fef3031c490>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7fef3031c4d0>,
#  'user': <gensim.models.keyedvectors.Vocab at 0x7fef3031c510>,
#  'coki': <gensim.models.keyedvectors.Vocab at 0x7fef3031c550>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7fef3031c590>,
#  'peopl': <gensim.models.keyedvectors.Vocab at 0x7fef3031c5d0>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7fef3031c610>,
#  'esenti': <gensim.models.keyedvectors.Vocab at 0x7fef3031c650>,
#  'oil': <gensim.models.keyedvectors.Vocab at 0x7fef3031c690>,
#  'chemic': <gensim.models.keyedvectors.Vocab at 0x7fef3031c6d0>,
#  'euro': <gensim.models.keyedvectors.Vocab at 0x7fef3031c710>,
#  'blame': <gensim.models.keyedvectors.Vocab at 0x7fef3031c750>,
#  'conced': <gensim.models.keyedvectors.Vocab at 0x7fef3031c790>,
#  'goal': <gensim.models.keyedvectors.Vocab at 0x7fef3031c7d0>,
#  'roney': <gensim.models.keyedvectors.Vocab at 0x7fef3031c810>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7fef3031c850>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x7fef3031c890>,
#  'fre': <gensim.models.keyedvectors.Vocab at 0x7fef3031c8d0>,
#  'kick': <gensim.models.keyedvectors.Vocab at 0x7fef3031c910>,
#  'bale': <gensim.models.keyedvectors.Vocab at 0x7fef3031c950>,
#  'littl': <gensim.models.keyedvectors.Vocab at 0x7fef3031c990>,
#  'dude': <gensim.models.keyedvectors.Vocab at 0x7fef3031c9d0>,
#  'baday': <gensim.models.keyedvectors.Vocab at 0x7fef3031ca10>,
#  'coneofsham': <gensim.models.keyedvectors.Vocab at 0x7fef3031ca50>,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x7fef3031ca90>,
#  'pise': <gensim.models.keyedvectors.Vocab at 0x7fef3031cad0>,
#  'funi': <gensim.models.keyedvectors.Vocab at 0x7fef3031cb10>,
#  'laugh': <gensim.models.keyedvectors.Vocab at 0x7fef3031cb50>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x7fef3031cb90>,
#  'hapi': <gensim.models.keyedvectors.Vocab at 0x7fef3031cbd0>,
#  'wine': <gensim.models.keyedvectors.Vocab at 0x7fef3031cc10>,
#  'tol': <gensim.models.keyedvectors.Vocab at 0x7fef3031cc50>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7fef3031cc90>,
#  'weekend': <gensim.models.keyedvectors.Vocab at 0x7fef3031ccd0>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7fef3031cd10>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x7fef3031cd50>,
#  'lumpi': <gensim.models.keyedvectors.Vocab at 0x7fef3031cd90>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7fef3031cdd0>,
#  'prove': <gensim.models.keyedvectors.Vocab at 0x7fef3031ce10>,
#  'tgif': <gensim.models.keyedvectors.Vocab at 0x7fef3031ce50>,
#  'gamedev': <gensim.models.keyedvectors.Vocab at 0x7fef3031ce90>,
#  'indiedev': <gensim.models.keyedvectors.Vocab at 0x7fef3031ced0>,
#  'indiegamedev': <gensim.models.keyedvectors.Vocab at 0x7fef3031cf10>,
#  'squad': <gensim.models.keyedvectors.Vocab at 0x7fef3031cf50>,
#  'beauti': <gensim.models.keyedvectors.Vocab at 0x7fef3031cf90>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x7fef3031cfd0>,
#  'vendor': <gensim.models.keyedvectors.Vocab at 0x7fef30315050>,
#  'upsideoflorida': <gensim.models.keyedvectors.Vocab at 0x7fef30315090>,
#  'shopalysa': <gensim.models.keyedvectors.Vocab at 0x7fef303150d0>,
#  'medium': <gensim.models.keyedvectors.Vocab at 0x7fef30315110>,
#  'presconfer': <gensim.models.keyedvectors.Vocab at 0x7fef30315150>,
#  'antalya': <gensim.models.keyedvectors.Vocab at 0x7fef30315190>,
#  'turkey': <gensim.models.keyedvectors.Vocab at 0x7fef303151d0>,
#  'sunday': <gensim.models.keyedvectors.Vocab at 0x7fef30315210>,
#  'throwback': <gensim.models.keyedvectors.Vocab at 0x7fef30315250>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7fef30315290>,
#  'panel': <gensim.models.keyedvectors.Vocab at 0x7fef303152d0>,
#  'mediat': <gensim.models.keyedvectors.Vocab at 0x7fef30315310>,
#  'public': <gensim.models.keyedvectors.Vocab at 0x7fef30315350>,
#  'servic': <gensim.models.keyedvectors.Vocab at 0x7fef30315390>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7fef303153d0>,
#  'nightclub': <gensim.models.keyedvectors.Vocab at 0x7fef30315410>,
#  'god': <gensim.models.keyedvectors.Vocab at 0x7fef30315450>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x7fef30315490>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x7fef303154d0>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x7fef30315510>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x7fef30315550>,
#  'lose': <gensim.models.keyedvectors.Vocab at 0x7fef30315590>,
#  'famili': <gensim.models.keyedvectors.Vocab at 0x7fef303155d0>,
#  'forev': <gensim.models.keyedvectors.Vocab at 0x7fef30315610>,
#  'riporlando': <gensim.models.keyedvectors.Vocab at 0x7fef30315650>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7fef30315690>,
#  'chanc': <gensim.models.keyedvectors.Vocab at 0x7fef303156d0>,
#  'vote': <gensim.models.keyedvectors.Vocab at 0x7fef30315710>,
#  'presidenti': <gensim.models.keyedvectors.Vocab at 0x7fef30315750>,
#  'candid': <gensim.models.keyedvectors.Vocab at 0x7fef30315790>,
#  'excit': <gensim.models.keyedvectors.Vocab at 0x7fef303157d0>,
#  'cycl': <gensim.models.keyedvectors.Vocab at 0x7fef30315810>,
#  'lok': <gensim.models.keyedvectors.Vocab at 0x7fef30315850>,
#  'difer': <gensim.models.keyedvectors.Vocab at 0x7fef30315890>,
#  'alohafriday': <gensim.models.keyedvectors.Vocab at 0x7fef303158d0>,
#  'exist': <gensim.models.keyedvectors.Vocab at 0x7fef30315910>,
#  'positivevib': <gensim.models.keyedvectors.Vocab at 0x7fef30315950>,
#  'hawaian': <gensim.models.keyedvectors.Vocab at 0x7fef30315990>,
#  'fellow': <gensim.models.keyedvectors.Vocab at 0x7fef303159d0>,
#  'nohern': <gensim.models.keyedvectors.Vocab at 0x7fef30315a10>,
#  'sadley': <gensim.models.keyedvectors.Vocab at 0x7fef30315a50>,
#  'pas': <gensim.models.keyedvectors.Vocab at 0x7fef30315a90>,
#  'tonight': <gensim.models.keyedvectors.Vocab at 0x7fef30315ad0>,
#  'gawa': <gensim.models.keyedvectors.Vocab at 0x7fef30315b10>,
#  'sing': <gensim.models.keyedvectors.Vocab at 0x7fef30315b50>,
#  'chere': <gensim.models.keyedvectors.Vocab at 0x7fef30315b90>,
#  'fire': <gensim.models.keyedvectors.Vocab at 0x7fef30315bd0>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7fef30315c10>,
#  'monday': <gensim.models.keyedvectors.Vocab at 0x7fef30315c50>,
#  'cloudi': <gensim.models.keyedvectors.Vocab at 0x7fef30315c90>,
#  'weather': <gensim.models.keyedvectors.Vocab at 0x7fef30315cd0>,
#  'disabl': <gensim.models.keyedvectors.Vocab at 0x7fef30315d10>,
#  'oxygen': <gensim.models.keyedvectors.Vocab at 0x7fef30315d50>,
#  'godnight': <gensim.models.keyedvectors.Vocab at 0x7fef30315d90>,
#  'badmonday': <gensim.models.keyedvectors.Vocab at 0x7fef30315dd0>,
#  'unbeliev': <gensim.models.keyedvectors.Vocab at 0x7fef30315e10>,
#  'centuri': <gensim.models.keyedvectors.Vocab at 0x7fef30315e50>,
#  'ned': <gensim.models.keyedvectors.Vocab at 0x7fef30315e90>,
#  'someth': <gensim.models.keyedvectors.Vocab at 0x7fef30315ed0>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7fef30315f10>,
#  'neverump': <gensim.models.keyedvectors.Vocab at 0x7fef30315f50>,
#  'xenophobia': <gensim.models.keyedvectors.Vocab at 0x7fef30315f90>,
#  'taylorswift': <gensim.models.keyedvectors.Vocab at 0x7fef30315fd0>,
#  'bull': <gensim.models.keyedvectors.Vocab at 0x7fef30313050>,
#  'domin': <gensim.models.keyedvectors.Vocab at 0x7fef30313090>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x7fef303130d0>,
#  'whatev': <gensim.models.keyedvectors.Vocab at 0x7fef30313110>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7fef30313150>,
#  'morn': <gensim.models.keyedvectors.Vocab at 0x7fef30313190>,
#  'travelingram': <gensim.models.keyedvectors.Vocab at 0x7fef303131d0>,
#  'dalat': <gensim.models.keyedvectors.Vocab at 0x7fef30313210>,
#  'ripinkylif': <gensim.models.keyedvectors.Vocab at 0x7fef30313250>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x7fef30313290>,
#  'tel': <gensim.models.keyedvectors.Vocab at 0x7fef303132d0>,
#  'photoshop': <gensim.models.keyedvectors.Vocab at 0x7fef30313310>,
#  'enoughisenough': <gensim.models.keyedvectors.Vocab at 0x7fef30313350>,
#  'dontphotoshopeveryth': <gensim.models.keyedvectors.Vocab at 0x7fef30313390>,
#  'wheresalthenaturalphoto': <gensim.models.keyedvectors.Vocab at 0x7fef303133d0>,
#  'cedarpoint': <gensim.models.keyedvectors.Vocab at 0x7fef30313410>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x7fef30313450>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x7fef30313490>,
#  'valravn': <gensim.models.keyedvectors.Vocab at 0x7fef303134d0>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7fef30313510>,
#  'stope': <gensim.models.keyedvectors.Vocab at 0x7fef30313550>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7fef30313590>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7fef303135d0>,
#  'sunshin': <gensim.models.keyedvectors.Vocab at 0x7fef30313610>,
#  'finali': <gensim.models.keyedvectors.Vocab at 0x7fef30313650>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x7fef30313690>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x7fef303136d0>,
#  'youv': <gensim.models.keyedvectors.Vocab at 0x7fef30313710>,
#  'awhil': <gensim.models.keyedvectors.Vocab at 0x7fef30313750>,
#  'bokworm': <gensim.models.keyedvectors.Vocab at 0x7fef30313790>,
#  'ontothenextnovel': <gensim.models.keyedvectors.Vocab at 0x7fef303137d0>,
#  'knick': <gensim.models.keyedvectors.Vocab at 0x7fef30313810>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x7fef30313850>,
#  'playof': <gensim.models.keyedvectors.Vocab at 0x7fef30313890>,
#  'rol': <gensim.models.keyedvectors.Vocab at 0x7fef303138d0>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7fef30313910>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x7fef30313950>,
#  'network': <gensim.models.keyedvectors.Vocab at 0x7fef30313990>,
#  'embrac': <gensim.models.keyedvectors.Vocab at 0x7fef303139d0>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x7fef30313a10>,
#  'snake': <gensim.models.keyedvectors.Vocab at 0x7fef30313a50>,
#  'echeveria': <gensim.models.keyedvectors.Vocab at 0x7fef30313a90>,
#  'blomsflow': <gensim.models.keyedvectors.Vocab at 0x7fef30313ad0>,
#  'grow': <gensim.models.keyedvectors.Vocab at 0x7fef30313b10>,
#  'garden': <gensim.models.keyedvectors.Vocab at 0x7fef30313b50>,
#  'iphonesia': <gensim.models.keyedvectors.Vocab at 0x7fef30313b90>,
#  'bli': <gensim.models.keyedvectors.Vocab at 0x7fef30313bd0>,
#  'blom': <gensim.models.keyedvectors.Vocab at 0x7fef30313c10>,
#  'basilicabotanica': <gensim.models.keyedvectors.Vocab at 0x7fef30313c50>,
#  'amaz': <gensim.models.keyedvectors.Vocab at 0x7fef30313c90>,
#  'afirm': <gensim.models.keyedvectors.Vocab at 0x7fef30313cd0>,
#  'whenev': <gensim.models.keyedvectors.Vocab at 0x7fef30313d10>,
#  'goe': <gensim.models.keyedvectors.Vocab at 0x7fef30313d50>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x7fef30313d90>,
#  'fele': <gensim.models.keyedvectors.Vocab at 0x7fef30313dd0>,
#  'blue': <gensim.models.keyedvectors.Vocab at 0x7fef30313e10>,
#  'ilustr': <gensim.models.keyedvectors.Vocab at 0x7fef30313e50>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7fef30313e90>,
#  'gete': <gensim.models.keyedvectors.Vocab at 0x7fef30313ed0>,
#  'readi': <gensim.models.keyedvectors.Vocab at 0x7fef30313f10>,
#  'remov': <gensim.models.keyedvectors.Vocab at 0x7fef30313f50>,
#  'victum': <gensim.models.keyedvectors.Vocab at 0x7fef30313f90>,
#  'pulseclub': <gensim.models.keyedvectors.Vocab at 0x7fef30313fd0>,
#  'prayfororlando': <gensim.models.keyedvectors.Vocab at 0x7fef3030b050>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x7fef3030b090>,
#  'petunia': <gensim.models.keyedvectors.Vocab at 0x7fef3030b0d0>,
#  'concelebr': <gensim.models.keyedvectors.Vocab at 0x7fef3030b110>,
#  'albanpilgrimag': <gensim.models.keyedvectors.Vocab at 0x7fef3030b150>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7fef3030b190>,
#  'scumbageri': <gensim.models.keyedvectors.Vocab at 0x7fef3030b1d0>,
#  'begin': <gensim.models.keyedvectors.Vocab at 0x7fef3030b210>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x7fef3030b250>,
#  'zpamdelacruz': <gensim.models.keyedvectors.Vocab at 0x7fef3030b290>,
#  'wede': <gensim.models.keyedvectors.Vocab at 0x7fef3030b2d0>,
#  'dolor': <gensim.models.keyedvectors.Vocab at 0x7fef3030b310>,
#  'capa': <gensim.models.keyedvectors.Vocab at 0x7fef3030b350>,
#  'tarlac': <gensim.models.keyedvectors.Vocab at 0x7fef3030b390>,
#  'scourg': <gensim.models.keyedvectors.Vocab at 0x7fef3030b3d0>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x7fef3030b410>,
#  'baroqu': <gensim.models.keyedvectors.Vocab at 0x7fef3030b450>,
#  'piec': <gensim.models.keyedvectors.Vocab at 0x7fef3030b490>,
#  'piano': <gensim.models.keyedvectors.Vocab at 0x7fef3030b4d0>,
#  'beyond': <gensim.models.keyedvectors.Vocab at 0x7fef3030b510>,
#  'belief': <gensim.models.keyedvectors.Vocab at 0x7fef3030b550>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7fef3030b590>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x7fef3030b5d0>,
#  'peac': <gensim.models.keyedvectors.Vocab at 0x7fef3030b610>,
#  'rayo': <gensim.models.keyedvectors.Vocab at 0x7fef3030b650>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x7fef3030b690>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7fef3030b6d0>,
#  'hotvideo': <gensim.models.keyedvectors.Vocab at 0x7fef3030b710>,
#  'ascot': <gensim.models.keyedvectors.Vocab at 0x7fef3030b750>,
#  'babe': <gensim.models.keyedvectors.Vocab at 0x7fef3030b790>,
#  'fashion': <gensim.models.keyedvectors.Vocab at 0x7fef3030b7d0>,
#  'monochrom': <gensim.models.keyedvectors.Vocab at 0x7fef3030b810>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x7fef3030b850>,
#  'instahapyday': <gensim.models.keyedvectors.Vocab at 0x7fef3030b890>,
#  'wekendi': <gensim.models.keyedvectors.Vocab at 0x7fef3030b8d0>,
#  'selfi': <gensim.models.keyedvectors.Vocab at 0x7fef3030b910>,
#  'yolo': <gensim.models.keyedvectors.Vocab at 0x7fef3030b950>,
#  'xoxo': <gensim.models.keyedvectors.Vocab at 0x7fef3030b990>,
#  'likelik': <gensim.models.keyedvectors.Vocab at 0x7fef3030b9d0>,
#  'confer': <gensim.models.keyedvectors.Vocab at 0x7fef3030ba10>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7fef3030ba50>,
#  'mindset': <gensim.models.keyedvectors.Vocab at 0x7fef3030ba90>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x7fef3030bad0>,
#  'cultureofdevelop': <gensim.models.keyedvectors.Vocab at 0x7fef3030bb10>,
#  'organ': <gensim.models.keyedvectors.Vocab at 0x7fef3030bb50>,
#  'christina': <gensim.models.keyedvectors.Vocab at 0x7fef3030bb90>,
#  'grimi': <gensim.models.keyedvectors.Vocab at 0x7fef3030bbd0>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7fef3030bc10>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x7fef3030bc50>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x7fef3030bc90>,
#  'christinarip': <gensim.models.keyedvectors.Vocab at 0x7fef3030bcd0>,
#  'voic': <gensim.models.keyedvectors.Vocab at 0x7fef3030bd10>,
#  'christinagrimi': <gensim.models.keyedvectors.Vocab at 0x7fef3030bd50>,
#  'danc': <gensim.models.keyedvectors.Vocab at 0x7fef3030bd90>,
#  'roar': <gensim.models.keyedvectors.Vocab at 0x7fef3030bdd0>,
#  'preschol': <gensim.models.keyedvectors.Vocab at 0x7fef3030be10>,
#  'student': <gensim.models.keyedvectors.Vocab at 0x7fef3030be50>,
#  'proud': <gensim.models.keyedvectors.Vocab at 0x7fef3030be90>,
#  'reali': <gensim.models.keyedvectors.Vocab at 0x7fef3030bed0>,
#  'wife': <gensim.models.keyedvectors.Vocab at 0x7fef3030bf10>,
#  'ador': <gensim.models.keyedvectors.Vocab at 0x7fef3030bf50>,
#  'mi': <gensim.models.keyedvectors.Vocab at 0x7fef3030bf90>,
#  'poland': <gensim.models.keyedvectors.Vocab at 0x7fef3030bfd0>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7fef30301050>,
#  'surgeri': <gensim.models.keyedvectors.Vocab at 0x7fef30301090>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7fef303010d0>,
#  'bridget': <gensim.models.keyedvectors.Vocab at 0x7fef30301110>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x7fef30301150>,
#  'everyth': <gensim.models.keyedvectors.Vocab at 0x7fef30301190>,
#  'jealou': <gensim.models.keyedvectors.Vocab at 0x7fef303011d0>,
#  'chatiado': <gensim.models.keyedvectors.Vocab at 0x7fef30301210>,
#  'celebr': <gensim.models.keyedvectors.Vocab at 0x7fef30301250>,
#  'everi': <gensim.models.keyedvectors.Vocab at 0x7fef30301290>,
#  'fatherli': <gensim.models.keyedvectors.Vocab at 0x7fef303012d0>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x7fef30301310>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7fef30301350>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7fef30301390>,
#  'establish': <gensim.models.keyedvectors.Vocab at 0x7fef303013d0>,
#  'folx': <gensim.models.keyedvectors.Vocab at 0x7fef30301410>,
#  'rune': <gensim.models.keyedvectors.Vocab at 0x7fef30301450>,
#  'promot': <gensim.models.keyedvectors.Vocab at 0x7fef30301490>,
#  'greatn': <gensim.models.keyedvectors.Vocab at 0x7fef303014d0>,
#  'journey': <gensim.models.keyedvectors.Vocab at 0x7fef30301510>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x7fef30301550>,
#  'yeah': <gensim.models.keyedvectors.Vocab at 0x7fef30301590>,
#  'thejourneybegin': <gensim.models.keyedvectors.Vocab at 0x7fef303015d0>,
#  'helo': <gensim.models.keyedvectors.Vocab at 0x7fef30301610>,
#  'hotwet': <gensim.models.keyedvectors.Vocab at 0x7fef30301650>,
#  'venusexchang': <gensim.models.keyedvectors.Vocab at 0x7fef30301690>,
#  'brochur': <gensim.models.keyedvectors.Vocab at 0x7fef303016d0>,
#  'ariv': <gensim.models.keyedvectors.Vocab at 0x7fef30301710>,
#  'awork': <gensim.models.keyedvectors.Vocab at 0x7fef30301750>,
#  'solut': <gensim.models.keyedvectors.Vocab at 0x7fef30301790>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7fef303017d0>,
#  'stuf': <gensim.models.keyedvectors.Vocab at 0x7fef30301810>,
#  'hapen': <gensim.models.keyedvectors.Vocab at 0x7fef30301850>,
#  'florida': <gensim.models.keyedvectors.Vocab at 0x7fef30301890>,
#  'shote': <gensim.models.keyedvectors.Vocab at 0x7fef303018d0>,
#  'disneygatoratack': <gensim.models.keyedvectors.Vocab at 0x7fef30301910>,
#  'ferari': <gensim.models.keyedvectors.Vocab at 0x7fef30301950>,
#  'sake': <gensim.models.keyedvectors.Vocab at 0x7fef30301990>,
#  'championship': <gensim.models.keyedvectors.Vocab at 0x7fef303019d0>,
#  'clearli': <gensim.models.keyedvectors.Vocab at 0x7fef30301a10>,
#  'turn': <gensim.models.keyedvectors.Vocab at 0x7fef30301a50>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7fef30301a90>,
#  'ferarimerc': <gensim.models.keyedvectors.Vocab at 0x7fef30301ad0>,
#  'ace': <gensim.models.keyedvectors.Vocab at 0x7fef30301b10>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x7fef30301b50>,
#  'sek': <gensim.models.keyedvectors.Vocab at 0x7fef30301b90>,
#  'probe': <gensim.models.keyedvectors.Vocab at 0x7fef30301bd0>,
#  'udtapunjab': <gensim.models.keyedvectors.Vocab at 0x7fef30301c10>,
#  'leak': <gensim.models.keyedvectors.Vocab at 0x7fef30301c50>,
#  'finger': <gensim.models.keyedvectors.Vocab at 0x7fef30301c90>,
#  'amarind': <gensim.models.keyedvectors.Vocab at 0x7fef30301cd0>,
#  'wrape': <gensim.models.keyedvectors.Vocab at 0x7fef30301d10>,
#  'senseaboutmath': <gensim.models.keyedvectors.Vocab at 0x7fef30301d50>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7fef30301d90>,
#  'race': <gensim.models.keyedvectors.Vocab at 0x7fef30301dd0>,
#  'ident': <gensim.models.keyedvectors.Vocab at 0x7fef30301e10>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7fef30301e50>,
#  'regurgit': <gensim.models.keyedvectors.Vocab at 0x7fef30301e90>,
#  'cale': <gensim.models.keyedvectors.Vocab at 0x7fef30301ed0>,
#  'sometim': <gensim.models.keyedvectors.Vocab at 0x7fef30301f10>,
#  'rais': <gensim.models.keyedvectors.Vocab at 0x7fef30301f50>,
#  'brow': <gensim.models.keyedvectors.Vocab at 0x7fef30301f90>,
#  'golfstrengthandcondit': <gensim.models.keyedvectors.Vocab at 0x7fef30301fd0>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7fef3033a050>,
#  'felixfoisgolf': <gensim.models.keyedvectors.Vocab at 0x7fef3033a090>,
#  'greathonour': <gensim.models.keyedvectors.Vocab at 0x7fef3033a0d0>,
#  'carerconvo': <gensim.models.keyedvectors.Vocab at 0x7fef3033a110>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x7fef3033a150>,
#  'inov': <gensim.models.keyedvectors.Vocab at 0x7fef3033a190>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x7fef3033a1d0>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x7fef3033a210>,
#  'includ': <gensim.models.keyedvectors.Vocab at 0x7fef3033a250>,
#  'wateringhol': <gensim.models.keyedvectors.Vocab at 0x7fef3033a290>,
#  'cave': <gensim.models.keyedvectors.Vocab at 0x7fef3033a2d0>,
#  'mountaintop': <gensim.models.keyedvectors.Vocab at 0x7fef3033a310>,
#  'campfir': <gensim.models.keyedvectors.Vocab at 0x7fef3033a350>,
#  'altright': <gensim.models.keyedvectors.Vocab at 0x7fef3033a390>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7fef3033a3d0>,
#  'insecur': <gensim.models.keyedvectors.Vocab at 0x7fef3033a410>,
#  'lure': <gensim.models.keyedvectors.Vocab at 0x7fef3033a450>,
#  'whitesupremaci': <gensim.models.keyedvectors.Vocab at 0x7fef3033a490>,
#  'cari': <gensim.models.keyedvectors.Vocab at 0x7fef3033a4d0>,
#  'wouldnt': <gensim.models.keyedvectors.Vocab at 0x7fef3033a510>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7fef3033a550>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x7fef3033a590>,
#  'wont': <gensim.models.keyedvectors.Vocab at 0x7fef3033a5d0>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x7fef3033a610>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7fef3033a650>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x7fef3033a690>,
#  'teror': <gensim.models.keyedvectors.Vocab at 0x7fef3033a6d0>,
#  'wors': <gensim.models.keyedvectors.Vocab at 0x7fef3033a710>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x7fef3033a750>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x7fef3033a790>,
#  'heal': <gensim.models.keyedvectors.Vocab at 0x7fef3033a7d0>,
#  'bodi': <gensim.models.keyedvectors.Vocab at 0x7fef3033a810>,
#  'altwaystoh': <gensim.models.keyedvectors.Vocab at 0x7fef3033a850>,
#  'healthi': <gensim.models.keyedvectors.Vocab at 0x7fef3033a890>,
#  'woho': <gensim.models.keyedvectors.Vocab at 0x7fef3033a8d0>,
#  'wek': <gensim.models.keyedvectors.Vocab at 0x7fef3033a910>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7fef3033a950>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x7fef3033a990>,
#  'rehears': <gensim.models.keyedvectors.Vocab at 0x7fef3033a9d0>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x7fef3033aa10>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7fef3033aa50>,
#  'anounc': <gensim.models.keyedvectors.Vocab at 0x7fef3033aa90>,
#  'midwek': <gensim.models.keyedvectors.Vocab at 0x7fef3033aad0>,
#  'newmus': <gensim.models.keyedvectors.Vocab at 0x7fef3033ab10>,
#  'watchthispac': <gensim.models.keyedvectors.Vocab at 0x7fef3033ab50>,
#  'guitar': <gensim.models.keyedvectors.Vocab at 0x7fef3033ab90>,
#  'chanel': <gensim.models.keyedvectors.Vocab at 0x7fef3033abd0>,
#  'fuss': <gensim.models.keyedvectors.Vocab at 0x7fef3033ac10>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7fef3033ac50>,
#  'episod': <gensim.models.keyedvectors.Vocab at 0x7fef3033ac90>,
#  'oflin': <gensim.models.keyedvectors.Vocab at 0x7fef3033acd0>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7fef3033ad10>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7fef3033ad50>,
#  'snapchat': <gensim.models.keyedvectors.Vocab at 0x7fef3033ad90>,
#  'redhead': <gensim.models.keyedvectors.Vocab at 0x7fef3033add0>,
#  'vermilionr': <gensim.models.keyedvectors.Vocab at 0x7fef3033ae10>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7fef3033ae50>,
#  'incred': <gensim.models.keyedvectors.Vocab at 0x7fef3033ae90>,
#  'receiv': <gensim.models.keyedvectors.Vocab at 0x7fef3033aed0>,
#  'acept': <gensim.models.keyedvectors.Vocab at 0x7fef3033af10>,
#  'letter': <gensim.models.keyedvectors.Vocab at 0x7fef3033af50>,
#  'master': <gensim.models.keyedvectors.Vocab at 0x7fef3033af90>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x7fef3033afd0>,
#  'octob': <gensim.models.keyedvectors.Vocab at 0x7fef30333050>,
#  'godtim': <gensim.models.keyedvectors.Vocab at 0x7fef30333090>,
#  'histori': <gensim.models.keyedvectors.Vocab at 0x7fef303330d0>,
#  'daughter': <gensim.models.keyedvectors.Vocab at 0x7fef30333110>,
#  'ride': <gensim.models.keyedvectors.Vocab at 0x7fef30333150>,
#  'bike': <gensim.models.keyedvectors.Vocab at 0x7fef30333190>,
#  'driveway': <gensim.models.keyedvectors.Vocab at 0x7fef303331d0>,
#  'enjoy': <gensim.models.keyedvectors.Vocab at 0x7fef30333210>,
#  'sumeim': <gensim.models.keyedvectors.Vocab at 0x7fef30333250>,
#  'memori': <gensim.models.keyedvectors.Vocab at 0x7fef30333290>,
#  'station': <gensim.models.keyedvectors.Vocab at 0x7fef303332d0>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7fef30333310>,
#  'cours': <gensim.models.keyedvectors.Vocab at 0x7fef30333350>,
#  'alway': <gensim.models.keyedvectors.Vocab at 0x7fef30333390>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x7fef303333d0>,
#  'gona': <gensim.models.keyedvectors.Vocab at 0x7fef30333410>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7fef30333450>,
#  'anytim': <gensim.models.keyedvectors.Vocab at 0x7fef30333490>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x7fef303334d0>,
#  'coupl': <gensim.models.keyedvectors.Vocab at 0x7fef30333510>,
#  'nake': <gensim.models.keyedvectors.Vocab at 0x7fef30333550>,
#  'japanes': <gensim.models.keyedvectors.Vocab at 0x7fef30333590>,
#  'hump': <gensim.models.keyedvectors.Vocab at 0x7fef303335d0>,
#  'humper': <gensim.models.keyedvectors.Vocab at 0x7fef30333610>,
#  'edwardsvil': <gensim.models.keyedvectors.Vocab at 0x7fef30333650>,
#  'pensylvania': <gensim.models.keyedvectors.Vocab at 0x7fef30333690>,
#  'personalis': <gensim.models.keyedvectors.Vocab at 0x7fef303336d0>,
#  'shop': <gensim.models.keyedvectors.Vocab at 0x7fef30333710>,
#  'col': <gensim.models.keyedvectors.Vocab at 0x7fef30333750>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7fef30333790>,
#  'truli': <gensim.models.keyedvectors.Vocab at 0x7fef303337d0>,
#  'sick': <gensim.models.keyedvectors.Vocab at 0x7fef30333810>,
#  'trump': <gensim.models.keyedvectors.Vocab at 0x7fef30333850>,
#  'obama': <gensim.models.keyedvectors.Vocab at 0x7fef30333890>,
#  'resign': <gensim.models.keyedvectors.Vocab at 0x7fef303338d0>,
#  'chang': <gensim.models.keyedvectors.Vocab at 0x7fef30333910>,
#  'nashviletour': <gensim.models.keyedvectors.Vocab at 0x7fef30333950>,
#  'nashvileforev': <gensim.models.keyedvectors.Vocab at 0x7fef30333990>,
#  'eurusd': <gensim.models.keyedvectors.Vocab at 0x7fef303339d0>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x7fef30333a10>,
#  'barier': <gensim.models.keyedvectors.Vocab at 0x7fef30333a50>,
#  'jump': <gensim.models.keyedvectors.Vocab at 0x7fef30333a90>,
#  'fresh': <gensim.models.keyedvectors.Vocab at 0x7fef30333ad0>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7fef30333b10>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x7fef30333b50>,
#  'stil': <gensim.models.keyedvectors.Vocab at 0x7fef30333b90>,
#  'wrap': <gensim.models.keyedvectors.Vocab at 0x7fef30333bd0>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x7fef30333c10>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x7fef30333c50>,
#  'destroy': <gensim.models.keyedvectors.Vocab at 0x7fef30333c90>,
#  'bake': <gensim.models.keyedvectors.Vocab at 0x7fef30333cd0>,
#  'eyelid': <gensim.models.keyedvectors.Vocab at 0x7fef30333d10>,
#  'vigilfororlando': <gensim.models.keyedvectors.Vocab at 0x7fef30333d50>,
#  'harp': <gensim.models.keyedvectors.Vocab at 0x7fef30333d90>,
#  'clonakilti': <gensim.models.keyedvectors.Vocab at 0x7fef30333dd0>,
#  'ihavenofriend': <gensim.models.keyedvectors.Vocab at 0x7fef30333e10>,
#  'someonecomewithm': <gensim.models.keyedvectors.Vocab at 0x7fef30333e50>,
#  'relax': <gensim.models.keyedvectors.Vocab at 0x7fef30333e90>,
#  'icon': <gensim.models.keyedvectors.Vocab at 0x7fef30333ed0>,
#  'woman': <gensim.models.keyedvectors.Vocab at 0x7fef30333f10>,
#  'sundaymorn': <gensim.models.keyedvectors.Vocab at 0x7fef30333f50>,
#  'marilynmonro': <gensim.models.keyedvectors.Vocab at 0x7fef30333f90>,
#  'interest': <gensim.models.keyedvectors.Vocab at 0x7fef30333fd0>,
#  'linguist': <gensim.models.keyedvectors.Vocab at 0x7fef3032c050>,
#  'doesnt': <gensim.models.keyedvectors.Vocab at 0x7fef3032c090>,
#  'adr': <gensim.models.keyedvectors.Vocab at 0x7fef3032c0d0>,
#  'racism': <gensim.models.keyedvectors.Vocab at 0x7fef3032c110>,
#  'raciolinguist': <gensim.models.keyedvectors.Vocab at 0x7fef3032c150>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7fef3032c190>,
#  'belov': <gensim.models.keyedvectors.Vocab at 0x7fef3032c1d0>,
#  'recov': <gensim.models.keyedvectors.Vocab at 0x7fef3032c210>,
#  'apl': <gensim.models.keyedvectors.Vocab at 0x7fef3032c250>,
#  'marvel': <gensim.models.keyedvectors.Vocab at 0x7fef3032c290>,
#  'song': <gensim.models.keyedvectors.Vocab at 0x7fef3032c2d0>,
#  'musica': <gensim.models.keyedvectors.Vocab at 0x7fef3032c310>,
#  'wed': <gensim.models.keyedvectors.Vocab at 0x7fef3032c350>,
#  'ripchristina': <gensim.models.keyedvectors.Vocab at 0x7fef3032c390>,
#  'adel': <gensim.models.keyedvectors.Vocab at 0x7fef3032c3d0>,
#  'vine': <gensim.models.keyedvectors.Vocab at 0x7fef3032c410>,
#  'mock': <gensim.models.keyedvectors.Vocab at 0x7fef3032c450>,
#  'brexit': <gensim.models.keyedvectors.Vocab at 0x7fef3032c490>,
#  'spel': <gensim.models.keyedvectors.Vocab at 0x7fef3032c4d0>,
#  'referendum': <gensim.models.keyedvectors.Vocab at 0x7fef3032c510>,
#  'comerzbank': <gensim.models.keyedvectors.Vocab at 0x7fef3032c550>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x7fef3032c590>,
#  'benefit': <gensim.models.keyedvectors.Vocab at 0x7fef3032c5d0>,
#  'cucumb': <gensim.models.keyedvectors.Vocab at 0x7fef3032c610>,
#  'pinoy': <gensim.models.keyedvectors.Vocab at 0x7fef3032c650>,
#  'folowm': <gensim.models.keyedvectors.Vocab at 0x7fef3032c690>,
#  'iger': <gensim.models.keyedvectors.Vocab at 0x7fef3032c6d0>,
#  'instagod': <gensim.models.keyedvectors.Vocab at 0x7fef3032c710>,
#  'toradora': <gensim.models.keyedvectors.Vocab at 0x7fef3032c750>,
#  'anim': <gensim.models.keyedvectors.Vocab at 0x7fef3032c790>,
#  'animedit': <gensim.models.keyedvectors.Vocab at 0x7fef3032c7d0>,
#  'breakup': <gensim.models.keyedvectors.Vocab at 0x7fef3032c810>,
#  'alon': <gensim.models.keyedvectors.Vocab at 0x7fef3032c850>,
#  'lone': <gensim.models.keyedvectors.Vocab at 0x7fef3032c890>,
#  'lap': <gensim.models.keyedvectors.Vocab at 0x7fef3032c8d0>,
#  'pol': <gensim.models.keyedvectors.Vocab at 0x7fef3032c910>,
#  'pick': <gensim.models.keyedvectors.Vocab at 0x7fef3032c950>,
#  'membership': <gensim.models.keyedvectors.Vocab at 0x7fef3032c990>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x7fef3032c9d0>,
#  'cotd': <gensim.models.keyedvectors.Vocab at 0x7fef3032ca10>,
#  'polar': <gensim.models.keyedvectors.Vocab at 0x7fef3032ca50>,
#  'bear': <gensim.models.keyedvectors.Vocab at 0x7fef3032ca90>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7fef3032cad0>,
#  'cold': <gensim.models.keyedvectors.Vocab at 0x7fef3032cb10>,
#  'loke': <gensim.models.keyedvectors.Vocab at 0x7fef3032cb50>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7fef3032cb90>,
#  'muslim': <gensim.models.keyedvectors.Vocab at 0x7fef3032cbd0>,
#  'asasin': <gensim.models.keyedvectors.Vocab at 0x7fef3032cc10>,
#  'snapi': <gensim.models.keyedvectors.Vocab at 0x7fef3032cc50>,
#  'fotbal': <gensim.models.keyedvectors.Vocab at 0x7fef3032cc90>,
#  'fringesqcbagsum': <gensim.models.keyedvectors.Vocab at 0x7fef3032ccd0>,
#  'nochebuena': <gensim.models.keyedvectors.Vocab at 0x7fef3032cd10>,
#  'lasvega': <gensim.models.keyedvectors.Vocab at 0x7fef3032cd50>,
#  'vega': <gensim.models.keyedvectors.Vocab at 0x7fef3032cd90>,
#  'strip': <gensim.models.keyedvectors.Vocab at 0x7fef3032cdd0>,
#  'fleuret': <gensim.models.keyedvectors.Vocab at 0x7fef3032ce10>,
#  'instaboyinstamansefieseptumfriend': <gensim.models.keyedvectors.Vocab at 0x7fef3032ce50>,
#  'smilesblackandwhit': <gensim.models.keyedvectors.Vocab at 0x7fef3032ce90>,
#  'branch': <gensim.models.keyedvectors.Vocab at 0x7fef3032ced0>,
#  'raini': <gensim.models.keyedvectors.Vocab at 0x7fef3032cf10>,
#  'write': <gensim.models.keyedvectors.Vocab at 0x7fef3032cf50>,
#  'tear': <gensim.models.keyedvectors.Vocab at 0x7fef3032cf90>,
#  'fli': <gensim.models.keyedvectors.Vocab at 0x7fef3032cfd0>,
#  'bird': <gensim.models.keyedvectors.Vocab at 0x7fef30326050>,
#  'haiku': <gensim.models.keyedvectors.Vocab at 0x7fef30326090>,
#  'micropoetri': <gensim.models.keyedvectors.Vocab at 0x7fef303260d0>,
#  'buton': <gensim.models.keyedvectors.Vocab at 0x7fef30326110>,
#  'mail': <gensim.models.keyedvectors.Vocab at 0x7fef30326150>,
#  'preti': <gensim.models.keyedvectors.Vocab at 0x7fef30326190>,
#  'jewelrymak': <gensim.models.keyedvectors.Vocab at 0x7fef303261d0>,
#  'driver': <gensim.models.keyedvectors.Vocab at 0x7fef30326210>,
#  'femal': <gensim.models.keyedvectors.Vocab at 0x7fef30326250>,
#  'mose': <gensim.models.keyedvectors.Vocab at 0x7fef30326290>,
#  'river': <gensim.models.keyedvectors.Vocab at 0x7fef303262d0>,
#  'weston': <gensim.models.keyedvectors.Vocab at 0x7fef30326310>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x7fef30326350>,
#  'crew': <gensim.models.keyedvectors.Vocab at 0x7fef30326390>,
#  'afterpa': <gensim.models.keyedvectors.Vocab at 0x7fef303263d0>,
#  'japan': <gensim.models.keyedvectors.Vocab at 0x7fef30326410>,
#  'madeinjapan': <gensim.models.keyedvectors.Vocab at 0x7fef30326450>,
#  'cute': <gensim.models.keyedvectors.Vocab at 0x7fef30326490>,
#  'cawai': <gensim.models.keyedvectors.Vocab at 0x7fef303264d0>,
#  'strawberi': <gensim.models.keyedvectors.Vocab at 0x7fef30326510>,
#  'tomato': <gensim.models.keyedvectors.Vocab at 0x7fef30326550>,
#  'arent': <gensim.models.keyedvectors.Vocab at 0x7fef30326590>,
#  'protest': <gensim.models.keyedvectors.Vocab at 0x7fef303265d0>,
#  'republican': <gensim.models.keyedvectors.Vocab at 0x7fef30326610>,
#  'wonthey': <gensim.models.keyedvectors.Vocab at 0x7fef30326650>,
#  'fuher': <gensim.models.keyedvectors.Vocab at 0x7fef30326690>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7fef303266d0>,
#  'spend': <gensim.models.keyedvectors.Vocab at 0x7fef30326710>,
#  'updat': <gensim.models.keyedvectors.Vocab at 0x7fef30326750>,
#  'analyt': <gensim.models.keyedvectors.Vocab at 0x7fef30326790>,
#  'photoftheday': <gensim.models.keyedvectors.Vocab at 0x7fef303267d0>,
#  'anyon': <gensim.models.keyedvectors.Vocab at 0x7fef30326810>,
#  'date': <gensim.models.keyedvectors.Vocab at 0x7fef30326850>,
#  'becam': <gensim.models.keyedvectors.Vocab at 0x7fef30326890>,
#  'corupt': <gensim.models.keyedvectors.Vocab at 0x7fef303268d0>,
#  'emailg': <gensim.models.keyedvectors.Vocab at 0x7fef30326910>,
#  'hilari': <gensim.models.keyedvectors.Vocab at 0x7fef30326950>,
#  'shame': <gensim.models.keyedvectors.Vocab at 0x7fef30326990>,
#  'disgrac': <gensim.models.keyedvectors.Vocab at 0x7fef303269d0>,
#  'ridicul': <gensim.models.keyedvectors.Vocab at 0x7fef30326a10>,
#  'stupid': <gensim.models.keyedvectors.Vocab at 0x7fef30326a50>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7fef30326a90>,
#  'negligencewhi': <gensim.models.keyedvectors.Vocab at 0x7fef30326ad0>,
#  'sachintendulkar': <gensim.models.keyedvectors.Vocab at 0x7fef30326b10>,
#  'instal': <gensim.models.keyedvectors.Vocab at 0x7fef30326b50>,
#  'thbihday': <gensim.models.keyedvectors.Vocab at 0x7fef30326b90>,
#  'bestfriend': <gensim.models.keyedvectors.Vocab at 0x7fef30326bd0>,
#  'impoant': <gensim.models.keyedvectors.Vocab at 0x7fef30326c10>,
#  'mater': <gensim.models.keyedvectors.Vocab at 0x7fef30326c50>,
#  'pohu': <gensim.models.keyedvectors.Vocab at 0x7fef30326c90>,
#  'chri': <gensim.models.keyedvectors.Vocab at 0x7fef30326cd0>,
#  'evan': <gensim.models.keyedvectors.Vocab at 0x7fef30326d10>,
#  'actor': <gensim.models.keyedvectors.Vocab at 0x7fef30326d50>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x7fef30326d90>,
#  'chrisevan': <gensim.models.keyedvectors.Vocab at 0x7fef30326dd0>,
#  'hea': <gensim.models.keyedvectors.Vocab at 0x7fef30326e10>,
#  'prayer': <gensim.models.keyedvectors.Vocab at 0x7fef30326e50>,
#  'murder': <gensim.models.keyedvectors.Vocab at 0x7fef30326e90>,
#  'demo': <gensim.models.keyedvectors.Vocab at 0x7fef30326ed0>,
#  'album': <gensim.models.keyedvectors.Vocab at 0x7fef30326f10>,
#  'newalbum': <gensim.models.keyedvectors.Vocab at 0x7fef30326f50>,
#  'indi': <gensim.models.keyedvectors.Vocab at 0x7fef30326f90>,
#  'echob': <gensim.models.keyedvectors.Vocab at 0x7fef30326fd0>,
#  'lion': <gensim.models.keyedvectors.Vocab at 0x7fef30321050>,
#  'webmaret': <gensim.models.keyedvectors.Vocab at 0x7fef30321090>,
#  'comun': <gensim.models.keyedvectors.Vocab at 0x7fef303210d0>,
#  'manag': <gensim.models.keyedvectors.Vocab at 0x7fef30321110>,
#  'nzdusd': <gensim.models.keyedvectors.Vocab at 0x7fef30321150>,
#  'target': <gensim.models.keyedvectors.Vocab at 0x7fef30321190>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7fef303211d0>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7fef30321210>,
#  'bihdayweksuck': <gensim.models.keyedvectors.Vocab at 0x7fef30321250>,
#  'bithday': <gensim.models.keyedvectors.Vocab at 0x7fef30321290>,
#  'blese': <gensim.models.keyedvectors.Vocab at 0x7fef303212d0>,
#  'ladi': <gensim.models.keyedvectors.Vocab at 0x7fef30321310>,
#  'hapiest': <gensim.models.keyedvectors.Vocab at 0x7fef30321350>,
#  'disneysmagickingdom': <gensim.models.keyedvectors.Vocab at 0x7fef30321390>,
#  'disney': <gensim.models.keyedvectors.Vocab at 0x7fef303213d0>,
#  'magickingdom': <gensim.models.keyedvectors.Vocab at 0x7fef30321410>,
#  'disneyland': <gensim.models.keyedvectors.Vocab at 0x7fef30321450>,
#  'kinda': <gensim.models.keyedvectors.Vocab at 0x7fef30321490>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7fef303214d0>,
#  'exclaim': <gensim.models.keyedvectors.Vocab at 0x7fef30321510>,
#  'blain': <gensim.models.keyedvectors.Vocab at 0x7fef30321550>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x7fef30321590>,
#  'nite': <gensim.models.keyedvectors.Vocab at 0x7fef303215d0>,
#  'listen': <gensim.models.keyedvectors.Vocab at 0x7fef30321610>,
#  'fredom': <gensim.models.keyedvectors.Vocab at 0x7fef30321650>,
#  'efo': <gensim.models.keyedvectors.Vocab at 0x7fef30321690>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x7fef303216d0>,
#  'mere': <gensim.models.keyedvectors.Vocab at 0x7fef30321710>,
#  'store': <gensim.models.keyedvectors.Vocab at 0x7fef30321750>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x7fef30321790>,
#  'theodor': <gensim.models.keyedvectors.Vocab at 0x7fef303217d0>,
#  'rosevelt': <gensim.models.keyedvectors.Vocab at 0x7fef30321810>,
#  'yal': <gensim.models.keyedvectors.Vocab at 0x7fef30321850>,
#  'aint': <gensim.models.keyedvectors.Vocab at 0x7fef30321890>,
#  'comit': <gensim.models.keyedvectors.Vocab at 0x7fef303218d0>,
#  'trust': <gensim.models.keyedvectors.Vocab at 0x7fef30321910>,
#  'faith': <gensim.models.keyedvectors.Vocab at 0x7fef30321950>,
#  'micheleobama': <gensim.models.keyedvectors.Vocab at 0x7fef30321990>,
#  'gorila': <gensim.models.keyedvectors.Vocab at 0x7fef303219d0>,
#  'racist': <gensim.models.keyedvectors.Vocab at 0x7fef30321a10>,
#  'newarkfestiv': <gensim.models.keyedvectors.Vocab at 0x7fef30321a50>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x7fef30321a90>,
#  'broken': <gensim.models.keyedvectors.Vocab at 0x7fef30321ad0>,
#  'netflix': <gensim.models.keyedvectors.Vocab at 0x7fef30321b10>,
#  'mochithepug': <gensim.models.keyedvectors.Vocab at 0x7fef30321b50>,
#  'puglif': <gensim.models.keyedvectors.Vocab at 0x7fef30321b90>,
#  'thathen': <gensim.models.keyedvectors.Vocab at 0x7fef30321bd0>,
#  'whatbusin': <gensim.models.keyedvectors.Vocab at 0x7fef30321c10>,
#  'usual': <gensim.models.keyedvectors.Vocab at 0x7fef30321c50>,
#  'dick': <gensim.models.keyedvectors.Vocab at 0x7fef30321c90>,
#  'suckin': <gensim.models.keyedvectors.Vocab at 0x7fef30321cd0>,
#  'tequila': <gensim.models.keyedvectors.Vocab at 0x7fef30321d10>,
#  'lovin': <gensim.models.keyedvectors.Vocab at 0x7fef30321d50>,
#  'slut': <gensim.models.keyedvectors.Vocab at 0x7fef30321d90>,
#  'justalil': <gensim.models.keyedvectors.Vocab at 0x7fef30321dd0>,
#  'butstilontim': <gensim.models.keyedvectors.Vocab at 0x7fef30321e10>,
#  'smaler': <gensim.models.keyedvectors.Vocab at 0x7fef30321e50>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x7fef30321e90>,
#  'bari': <gensim.models.keyedvectors.Vocab at 0x7fef30321ed0>,
#  'probabl': <gensim.models.keyedvectors.Vocab at 0x7fef30321f10>,
#  'lie': <gensim.models.keyedvectors.Vocab at 0x7fef30321f50>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x7fef30321f90>,
#  'suck': <gensim.models.keyedvectors.Vocab at 0x7fef30321fd0>,
#  'golf': <gensim.models.keyedvectors.Vocab at 0x7fef3031b050>,
#  'everyon': <gensim.models.keyedvectors.Vocab at 0x7fef3031b090>,
#  'godmorn': <gensim.models.keyedvectors.Vocab at 0x7fef3031b0d0>,
#  'chaleng': <gensim.models.keyedvectors.Vocab at 0x7fef3031b110>,
#  'ap': <gensim.models.keyedvectors.Vocab at 0x7fef3031b150>,
#  'claim': <gensim.models.keyedvectors.Vocab at 0x7fef3031b190>,
#  'punjabi': <gensim.models.keyedvectors.Vocab at 0x7fef3031b1d0>,
#  'drugadict': <gensim.models.keyedvectors.Vocab at 0x7fef3031b210>,
#  'dare': <gensim.models.keyedvectors.Vocab at 0x7fef3031b250>,
#  'tracerequest': <gensim.models.keyedvectors.Vocab at 0x7fef3031b290>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x7fef3031b2d0>,
#  'depest': <gensim.models.keyedvectors.Vocab at 0x7fef3031b310>,
#  'condol': <gensim.models.keyedvectors.Vocab at 0x7fef3031b350>,
#  'zimbabw': <gensim.models.keyedvectors.Vocab at 0x7fef3031b390>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x7fef3031b3d0>,
#  'mato': <gensim.models.keyedvectors.Vocab at 0x7fef3031b410>,
#  'chapon': <gensim.models.keyedvectors.Vocab at 0x7fef3031b450>,
#  'saturday': <gensim.models.keyedvectors.Vocab at 0x7fef3031b490>,
#  'afternon': <gensim.models.keyedvectors.Vocab at 0x7fef3031b4d0>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x7fef3031b510>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7fef3031b550>,
#  'bolt': <gensim.models.keyedvectors.Vocab at 0x7fef3031b590>,
#  'bloke': <gensim.models.keyedvectors.Vocab at 0x7fef3031b5d0>,
#  'bing': <gensim.models.keyedvectors.Vocab at 0x7fef3031b610>,
#  'bong': <gensim.models.keyedvectors.Vocab at 0x7fef3031b650>,
#  'dawn': <gensim.models.keyedvectors.Vocab at 0x7fef3031b690>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x7fef3031b6d0>,
#  'se': <gensim.models.keyedvectors.Vocab at 0x7fef3031b710>,
# ...
#  'apeas': <gensim.models.keyedvectors.Vocab at 0x7fef3031bc50>,
#  'measur': <gensim.models.keyedvectors.Vocab at 0x7fef3031bc90>,
#  'gloucesterugbi': <gensim.models.keyedvectors.Vocab at 0x7fef3031bcd0>,
#  'togeth': <gensim.models.keyedvectors.Vocab at 0x7fef3031bd10>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x7fef3031bd50>,
#  'dandi': <gensim.models.keyedvectors.Vocab at 0x7fef3031bd90>,
#  'exuber': <gensim.models.keyedvectors.Vocab at 0x7fef3031bdd0>,
#  'depres': <gensim.models.keyedvectors.Vocab at 0x7fef3031be10>,
#  'hal': <gensim.models.keyedvectors.Vocab at 0x7fef3031be50>,
#  'halfempti': <gensim.models.keyedvectors.Vocab at 0x7fef3031be90>,
#  'mikeashley': <gensim.models.keyedvectors.Vocab at 0x7fef3031bed0>,
#  'sposdirectsham': <gensim.models.keyedvectors.Vocab at 0x7fef3031bf10>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x7fef3031bf50>,
#  'exampl': <gensim.models.keyedvectors.Vocab at 0x7fef3031bf90>,
#  'protect': <gensim.models.keyedvectors.Vocab at 0x7fef3031bfd0>,
#  'workersright': <gensim.models.keyedvectors.Vocab at 0x7fef30314050>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x7fef30314090>,
#  'europ': <gensim.models.keyedvectors.Vocab at 0x7fef303140d0>,
#  'euref': <gensim.models.keyedvectors.Vocab at 0x7fef30314110>,
#  'remain': <gensim.models.keyedvectors.Vocab at 0x7fef30314150>,
#  'stela': <gensim.models.keyedvectors.Vocab at 0x7fef30314190>,
#  'princ': <gensim.models.keyedvectors.Vocab at 0x7fef303141d0>,
#  'birdstelabadprinc': <gensim.models.keyedvectors.Vocab at 0x7fef30314210>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x7fef30314250>,
#  'check': <gensim.models.keyedvectors.Vocab at 0x7fef30314290>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x7fef303142d0>,
#  'alreadi': <gensim.models.keyedvectors.Vocab at 0x7fef30314310>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x7fef30314350>,
#  'ask': <gensim.models.keyedvectors.Vocab at 0x7fef30314390>,
#  'paicularli': <gensim.models.keyedvectors.Vocab at 0x7fef303143d0>,
#  'dificult': <gensim.models.keyedvectors.Vocab at 0x7fef30314410>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x7fef30314450>,
#  'devast': <gensim.models.keyedvectors.Vocab at 0x7fef30314490>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x7fef303144d0>,
#  'victim': <gensim.models.keyedvectors.Vocab at 0x7fef30314510>,
#  'hapin': <gensim.models.keyedvectors.Vocab at 0x7fef30314550>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7fef30314590>,
#  'manner': <gensim.models.keyedvectors.Vocab at 0x7fef303145d0>,
#  'margaret': <gensim.models.keyedvectors.Vocab at 0x7fef30314610>,
#  'runbeck': <gensim.models.keyedvectors.Vocab at 0x7fef30314650>,
#  'quot': <gensim.models.keyedvectors.Vocab at 0x7fef30314690>,
#  'inspir': <gensim.models.keyedvectors.Vocab at 0x7fef303146d0>,
#  'safe': <gensim.models.keyedvectors.Vocab at 0x7fef30314710>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7fef30314750>,
#  'acn': <gensim.models.keyedvectors.Vocab at 0x7fef30314790>,
#  'creat': <gensim.models.keyedvectors.Vocab at 0x7fef303147d0>,
#  'beat': <gensim.models.keyedvectors.Vocab at 0x7fef30314810>,
#  'makingbeat': <gensim.models.keyedvectors.Vocab at 0x7fef30314850>,
#  'thursday': <gensim.models.keyedvectors.Vocab at 0x7fef30314890>,
#  'istandard': <gensim.models.keyedvectors.Vocab at 0x7fef303148d0>,
#  'akaipro': <gensim.models.keyedvectors.Vocab at 0x7fef30314910>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7fef30314950>,
#  'wedingpay': <gensim.models.keyedvectors.Vocab at 0x7fef30314990>,
#  'wedingdr': <gensim.models.keyedvectors.Vocab at 0x7fef303149d0>,
#  'forward': <gensim.models.keyedvectors.Vocab at 0x7fef30314a10>,
#  'atend': <gensim.models.keyedvectors.Vocab at 0x7fef30314a50>,
#  'cipd': <gensim.models.keyedvectors.Vocab at 0x7fef30314a90>,
#  'workshop': <gensim.models.keyedvectors.Vocab at 0x7fef30314ad0>,
#  'onemoreday': <gensim.models.keyedvectors.Vocab at 0x7fef30314b10>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x7fef30314b50>,
#  'folow': <gensim.models.keyedvectors.Vocab at 0x7fef30314b90>,
#  'twitch': <gensim.models.keyedvectors.Vocab at 0x7fef30314bd0>,
#  'hypu': <gensim.models.keyedvectors.Vocab at 0x7fef30314c10>,
#  'stream': <gensim.models.keyedvectors.Vocab at 0x7fef30314c50>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x7fef30314c90>,
#  'verbal': <gensim.models.keyedvectors.Vocab at 0x7fef30314cd0>,
#  'abus': <gensim.models.keyedvectors.Vocab at 0x7fef30314d10>,
#  'adult': <gensim.models.keyedvectors.Vocab at 0x7fef30314d50>,
#  'ten': <gensim.models.keyedvectors.Vocab at 0x7fef30314d90>,
#  'countri': <gensim.models.keyedvectors.Vocab at 0x7fef30314dd0>,
#  'bomb': <gensim.models.keyedvectors.Vocab at 0x7fef30314e10>,
#  'stadium': <gensim.models.keyedvectors.Vocab at 0x7fef30314e50>,
#  'swalscha': <gensim.models.keyedvectors.Vocab at 0x7fef30314e90>,
#  'dejeun': <gensim.models.keyedvectors.Vocab at 0x7fef30314ed0>,
#  'lunch': <gensim.models.keyedvectors.Vocab at 0x7fef30314f10>,
#  'amoureux': <gensim.models.keyedvectors.Vocab at 0x7fef30314f50>,
#  'ilovethesecret': <gensim.models.keyedvectors.Vocab at 0x7fef30314f90>,
#  'lawofatract': <gensim.models.keyedvectors.Vocab at 0x7fef30314fd0>,
#  'quiz': <gensim.models.keyedvectors.Vocab at 0x7fef3030d050>,
#  'suce': <gensim.models.keyedvectors.Vocab at 0x7fef3030d090>,
#  'libtard': <gensim.models.keyedvectors.Vocab at 0x7fef3030d0d0>,
#  'liber': <gensim.models.keyedvectors.Vocab at 0x7fef3030d110>,
#  'polit': <gensim.models.keyedvectors.Vocab at 0x7fef3030d150>,
#  'pole': <gensim.models.keyedvectors.Vocab at 0x7fef3030d190>,
#  'rozthediva': <gensim.models.keyedvectors.Vocab at 0x7fef3030d1d0>,
#  'blackgirlspol': <gensim.models.keyedvectors.Vocab at 0x7fef3030d210>,
#  'bodyandpol': <gensim.models.keyedvectors.Vocab at 0x7fef3030d250>,
#  'argentina': <gensim.models.keyedvectors.Vocab at 0x7fef3030d290>,
#  'atack': <gensim.models.keyedvectors.Vocab at 0x7fef3030d2d0>,
#  'empti': <gensim.models.keyedvectors.Vocab at 0x7fef3030d310>,
#  'citi': <gensim.models.keyedvectors.Vocab at 0x7fef3030d350>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x7fef3030d390>,
#  'selfserv': <gensim.models.keyedvectors.Vocab at 0x7fef3030d3d0>,
#  'hypocrit': <gensim.models.keyedvectors.Vocab at 0x7fef3030d410>,
#  'kep': <gensim.models.keyedvectors.Vocab at 0x7fef3030d450>,
#  'bounc': <gensim.models.keyedvectors.Vocab at 0x7fef3030d490>,
#  'ball': <gensim.models.keyedvectors.Vocab at 0x7fef3030d4d0>,
#  'nimrod': <gensim.models.keyedvectors.Vocab at 0x7fef3030d510>,
#  'presid': <gensim.models.keyedvectors.Vocab at 0x7fef3030d550>,
#  'nohcarolina': <gensim.models.keyedvectors.Vocab at 0x7fef3030d590>,
#  'relect': <gensim.models.keyedvectors.Vocab at 0x7fef3030d5d0>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x7fef3030d610>,
#  'ksleg': <gensim.models.keyedvectors.Vocab at 0x7fef3030d650>,
#  'cannot': <gensim.models.keyedvectors.Vocab at 0x7fef3030d690>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7fef3030d6d0>,
#  'easili': <gensim.models.keyedvectors.Vocab at 0x7fef3030d710>,
#  'anywher': <gensim.models.keyedvectors.Vocab at 0x7fef3030d750>,
#  'alremgroup': <gensim.models.keyedvectors.Vocab at 0x7fef3030d790>,
#  'alyalshahawi': <gensim.models.keyedvectors.Vocab at 0x7fef3030d7d0>,
#  'photographerdubai': <gensim.models.keyedvectors.Vocab at 0x7fef3030d810>,
#  'mydubai': <gensim.models.keyedvectors.Vocab at 0x7fef3030d850>,
#  'sem': <gensim.models.keyedvectors.Vocab at 0x7fef3030d890>,
#  'montreal': <gensim.models.keyedvectors.Vocab at 0x7fef3030d8d0>,
#  'wash': <gensim.models.keyedvectors.Vocab at 0x7fef3030d910>,
#  'spirit': <gensim.models.keyedvectors.Vocab at 0x7fef3030d950>,
#  'enteain': <gensim.models.keyedvectors.Vocab at 0x7fef3030d990>,
#  'brisban': <gensim.models.keyedvectors.Vocab at 0x7fef3030d9d0>,
#  'wimbledon': <gensim.models.keyedvectors.Vocab at 0x7fef3030da10>,
#  'entrepreneur': <gensim.models.keyedvectors.Vocab at 0x7fef3030da50>,
#  'speaker': <gensim.models.keyedvectors.Vocab at 0x7fef3030da90>,
#  'confid': <gensim.models.keyedvectors.Vocab at 0x7fef3030dad0>,
#  'gala': <gensim.models.keyedvectors.Vocab at 0x7fef3030db10>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x7fef3030db50>,
#  'bipolar': <gensim.models.keyedvectors.Vocab at 0x7fef3030db90>,
#  'frikiegirl': <gensim.models.keyedvectors.Vocab at 0x7fef3030dbd0>,
#  'lucki': <gensim.models.keyedvectors.Vocab at 0x7fef3030dc10>,
#  'chinatown': <gensim.models.keyedvectors.Vocab at 0x7fef3030dc50>,
#  'mal': <gensim.models.keyedvectors.Vocab at 0x7fef3030dc90>,
#  'binondo': <gensim.models.keyedvectors.Vocab at 0x7fef3030dcd0>,
#  'pi': <gensim.models.keyedvectors.Vocab at 0x7fef3030dd10>,
#  'isnt': <gensim.models.keyedvectors.Vocab at 0x7fef3030dd50>,
#  'complet': <gensim.models.keyedvectors.Vocab at 0x7fef3030dd90>,
#  'uter': <gensim.models.keyedvectors.Vocab at 0x7fef3030ddd0>,
#  'moron': <gensim.models.keyedvectors.Vocab at 0x7fef3030de10>,
#  'trash': <gensim.models.keyedvectors.Vocab at 0x7fef3030de50>,
#  'america': <gensim.models.keyedvectors.Vocab at 0x7fef3030de90>,
#  'dad': <gensim.models.keyedvectors.Vocab at 0x7fef3030ded0>,
#  'magnetherapi': <gensim.models.keyedvectors.Vocab at 0x7fef3030df10>,
#  'sebo': <gensim.models.keyedvectors.Vocab at 0x7fef3030df50>,
#  'smilegsmil': <gensim.models.keyedvectors.Vocab at 0x7fef3030df90>,
#  'torio': <gensim.models.keyedvectors.Vocab at 0x7fef3030dfd0>,
#  'briliant': <gensim.models.keyedvectors.Vocab at 0x7fef30307050>,
#  'keter': <gensim.models.keyedvectors.Vocab at 0x7fef30307090>,
#  'custom': <gensim.models.keyedvectors.Vocab at 0x7fef303070d0>,
#  'screne': <gensim.models.keyedvectors.Vocab at 0x7fef30307110>,
#  'potp': <gensim.models.keyedvectors.Vocab at 0x7fef30307150>,
#  'shock': <gensim.models.keyedvectors.Vocab at 0x7fef30307190>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x7fef303071d0>,
#  'toraya': <gensim.models.keyedvectors.Vocab at 0x7fef30307210>,
#  'alamindah': <gensim.models.keyedvectors.Vocab at 0x7fef30307250>,
#  'carieunderwod': <gensim.models.keyedvectors.Vocab at 0x7fef30307290>,
#  'ber': <gensim.models.keyedvectors.Vocab at 0x7fef303072d0>,
#  'bridpo': <gensim.models.keyedvectors.Vocab at 0x7fef30307310>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7fef30307350>,
#  'beer': <gensim.models.keyedvectors.Vocab at 0x7fef30307390>,
#  'fest': <gensim.models.keyedvectors.Vocab at 0x7fef303073d0>,
#  'campsit': <gensim.models.keyedvectors.Vocab at 0x7fef30307410>,
#  'drunk': <gensim.models.keyedvectors.Vocab at 0x7fef30307450>,
#  'starstruck': <gensim.models.keyedvectors.Vocab at 0x7fef30307490>,
#  'repost': <gensim.models.keyedvectors.Vocab at 0x7fef303074d0>,
#  'propey': <gensim.models.keyedvectors.Vocab at 0x7fef30307510>,
#  'ocean': <gensim.models.keyedvectors.Vocab at 0x7fef30307550>,
#  'sydney': <gensim.models.keyedvectors.Vocab at 0x7fef30307590>,
#  'teach': <gensim.models.keyedvectors.Vocab at 0x7fef303075d0>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x7fef30307610>,
#  'pakistan': <gensim.models.keyedvectors.Vocab at 0x7fef30307650>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x7fef30307690>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x7fef303076d0>,
#  'countdown': <gensim.models.keyedvectors.Vocab at 0x7fef30307710>,
#  'nolefam': <gensim.models.keyedvectors.Vocab at 0x7fef30307750>,
#  'milan': <gensim.models.keyedvectors.Vocab at 0x7fef30307790>,
#  'stone': <gensim.models.keyedvectors.Vocab at 0x7fef303077d0>,
#  'rise': <gensim.models.keyedvectors.Vocab at 0x7fef30307810>,
#  'club': <gensim.models.keyedvectors.Vocab at 0x7fef30307850>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7fef30307890>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7fef303078d0>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x7fef30307910>,
#  'nobodi': <gensim.models.keyedvectors.Vocab at 0x7fef30307950>,
#  'el': <gensim.models.keyedvectors.Vocab at 0x7fef30307990>,
#  'crush': <gensim.models.keyedvectors.Vocab at 0x7fef303079d0>,
#  'wakow': <gensim.models.keyedvectors.Vocab at 0x7fef30307a10>,
#  'buz': <gensim.models.keyedvectors.Vocab at 0x7fef30307a50>,
#  'hokup': <gensim.models.keyedvectors.Vocab at 0x7fef30307a90>,
#  'engag': <gensim.models.keyedvectors.Vocab at 0x7fef30307ad0>,
#  'clasez': <gensim.models.keyedvectors.Vocab at 0x7fef30307b10>,
#  'risay': <gensim.models.keyedvectors.Vocab at 0x7fef30307b50>,
#  'risaypl': <gensim.models.keyedvectors.Vocab at 0x7fef30307b90>,
#  'legendari': <gensim.models.keyedvectors.Vocab at 0x7fef30307bd0>,
#  'unit': <gensim.models.keyedvectors.Vocab at 0x7fef30307c10>,
#  'rest': <gensim.models.keyedvectors.Vocab at 0x7fef30307c50>,
#  'proven': <gensim.models.keyedvectors.Vocab at 0x7fef30307c90>,
#  'firearm': <gensim.models.keyedvectors.Vocab at 0x7fef30307cd0>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x7fef30307d10>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x7fef30307d50>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7fef30307d90>,
#  'deni': <gensim.models.keyedvectors.Vocab at 0x7fef30307dd0>,
#  'jefreycwiliam': <gensim.models.keyedvectors.Vocab at 0x7fef30307e10>,
#  'butru': <gensim.models.keyedvectors.Vocab at 0x7fef30307e50>,
#  'babi': <gensim.models.keyedvectors.Vocab at 0x7fef30307e90>,
#  'babygirl': <gensim.models.keyedvectors.Vocab at 0x7fef30307ed0>,
#  'niec': <gensim.models.keyedvectors.Vocab at 0x7fef30307f10>,
#  'oneteamlincoln': <gensim.models.keyedvectors.Vocab at 0x7fef30307f50>,
#  'carowind': <gensim.models.keyedvectors.Vocab at 0x7fef30307f90>,
#  'rockthepark': <gensim.models.keyedvectors.Vocab at 0x7fef30307fd0>,
#  'timetogetmyjesuson': <gensim.models.keyedvectors.Vocab at 0x7fef30302050>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x7fef30302090>,
#  'dori': <gensim.models.keyedvectors.Vocab at 0x7fef303020d0>,
#  'ticket': <gensim.models.keyedvectors.Vocab at 0x7fef30302110>,
#  'minut': <gensim.models.keyedvectors.Vocab at 0x7fef30302150>,
#  'sixti': <gensim.models.keyedvectors.Vocab at 0x7fef30302190>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x7fef303021d0>,
#  'sanjapan': <gensim.models.keyedvectors.Vocab at 0x7fef30302210>,
#  'animeconvent': <gensim.models.keyedvectors.Vocab at 0x7fef30302250>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x7fef30302290>,
#  'septemb': <gensim.models.keyedvectors.Vocab at 0x7fef303022d0>,
#  'moto': <gensim.models.keyedvectors.Vocab at 0x7fef30302310>,
#  'tech': <gensim.models.keyedvectors.Vocab at 0x7fef30302350>,
#  'count': <gensim.models.keyedvectors.Vocab at 0x7fef30302390>,
#  'mondaymotiv': <gensim.models.keyedvectors.Vocab at 0x7fef303023d0>,
#  'livelifetothefulest': <gensim.models.keyedvectors.Vocab at 0x7fef30302410>,
#  'everydaycount': <gensim.models.keyedvectors.Vocab at 0x7fef30302450>,
#  'degr': <gensim.models.keyedvectors.Vocab at 0x7fef30302490>,
#  'ana': <gensim.models.keyedvectors.Vocab at 0x7fef303024d0>,
#  'clasmat': <gensim.models.keyedvectors.Vocab at 0x7fef30302510>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7fef30302550>,
#  'abl': <gensim.models.keyedvectors.Vocab at 0x7fef30302590>,
#  'supo': <gensim.models.keyedvectors.Vocab at 0x7fef303025d0>,
#  'event': <gensim.models.keyedvectors.Vocab at 0x7fef30302610>,
#  'brentwod': <gensim.models.keyedvectors.Vocab at 0x7fef30302650>,
#  'homesta': <gensim.models.keyedvectors.Vocab at 0x7fef30302690>,
#  'fund': <gensim.models.keyedvectors.Vocab at 0x7fef303026d0>,
#  'hapyhapi': <gensim.models.keyedvectors.Vocab at 0x7fef30302710>,
#  'kiten': <gensim.models.keyedvectors.Vocab at 0x7fef30302750>,
#  'blackiten': <gensim.models.keyedvectors.Vocab at 0x7fef30302790>,
#  'opoun': <gensim.models.keyedvectors.Vocab at 0x7fef303027d0>,
#  'cherish': <gensim.models.keyedvectors.Vocab at 0x7fef30302810>,
#  'themeowod': <gensim.models.keyedvectors.Vocab at 0x7fef30302850>,
#  'pupi': <gensim.models.keyedvectors.Vocab at 0x7fef30302890>,
#  'til': <gensim.models.keyedvectors.Vocab at 0x7fef303028d0>,
#  'pharel': <gensim.models.keyedvectors.Vocab at 0x7fef30302910>,
#  'wiliam': <gensim.models.keyedvectors.Vocab at 0x7fef30302950>,
#  'pharelwiliam': <gensim.models.keyedvectors.Vocab at 0x7fef30302990>,
#  'lyric': <gensim.models.keyedvectors.Vocab at 0x7fef303029d0>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x7fef30302a10>,
#  ...}

# %%
display_pca_scatterplot(w2v_model,
                        ['friend', 'great', 'love', 'life', 'girl', 'beauti', 'smile',
                         'summer', 'thank', 'time', 'today', 'weekend', 'father', 'polit',
                         'alway', 'year', 'best', 'tomorrow', 'land', 'cav', 'white', 'woman',
                         'friday', 'night', 'never', 'trump', 'much', 'lose', 'best', 'black',
                         'cleveland', 'poland', 'turkey', 'silver', 'gold', 'everydaycount',
                         'hate', 'clevelandcavali', 'michigan', 'liber', 'look', 'racist'])

# %% [markdown]
# ## TF-IDF

# %%
# tfidf_vectorizer = TfidfVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')
tfidf_vectorizer = TfidfVectorizer()
# TF-IDF feature matrix
tfidf_matrix = tfidf_vectorizer.fit_transform(combi['cleanTweet'])
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

# %%
w2v_model.wv.syn0.shape
# Out:
# (41206, 100)

# %%
def make_feature_vec(words, model, num_features, tfidf_scores):
    """
    Average the word vectors for a set of words
    """
    feature_vec = np.zeros((num_features,),dtype="float32")  # pre-initialize (for speed)
    nwords = 0.
    index2word_set = set(model.index2word)  # words known to the model

    for word in words:
        if word in index2word_set:
            nwords = nwords + 1.
            weight = 1
            if word in tfidf_scores:
                weight = tfidf_scores[word]
            feature_vec = np.add(feature_vec,model[word] * weight)

    feature_vec = np.divide(feature_vec, nwords)
    return feature_vec

def get_avg_feature_vecs(sents, model, num_features, tfidf_list):
    """
    Calculate average feature vectors for all reviews
    """
    counter = 0
    sent_feature_vecs = np.zeros((len(sents),num_features), dtype='float32')  # pre-initialize (for speed)

    feature_index = tfidf_matrix[counter,:].nonzero()[1]

    for sent in sents:
        sent_feature_vecs[counter] = make_feature_vec(sent, model, num_features, tfidf_list[counter])
        counter = counter + 1
    return sent_feature_vecs

# %%
index_value={i[1]:i[0] for i in tfidf_vectorizer.vocabulary_.items()}
fully_indexed = []
for row in tfidf_matrix:
    fully_indexed.append({index_value[column]:value for (column,value) in zip(row.indices,row.data)})

data = get_avg_feature_vecs(tokenized_tweet, w2v_model.wv, 100, fully_indexed)
data
# Out:
# array([[-0.01855512, -0.05743016, -0.00111349, ...,  0.03569216,
#         -0.21601808,  0.13951658],
#        [-0.00961645, -0.04630406, -0.04729081, ...,  0.01514739,
#         -0.15159118,  0.19921342],
#        [-0.18049507, -0.1344137 ,  0.29775155, ...,  0.02310868,
#         -0.5593955 ,  0.399947  ],
#        ...,
#        [-0.00353936, -0.0407644 , -0.0676999 , ...,  0.01665005,
#         -0.19917808,  0.22371416],
#        [-0.01861098, -0.15869994, -0.0980477 , ..., -0.13122591,
#         -0.8421667 ,  0.5992545 ],
#        [ 0.00587404, -0.08176929, -0.01481797, ...,  0.03494063,
#         -0.19909652,  0.21904409]], dtype=float32)

# %% [markdown]
# # Classification Models

# %%
train_data  = data[:31962]
# test_data   = data[25569:]
# train_label = combi['label'].to_numpy()[:25569]
# test_label  = combi['label'].to_numpy()[25569:]

# train_data.shape
# np.isnan(train_data).any()
train_data = np.nan_to_num(train_data)

# splitting data into training and validation set
X_train, X_test, y_train, y_test = train_test_split(train_data, train['label'], random_state=42, test_size=0.3)

# %%
# def model_Evaluate(model, xtest):
def modelResult(y_pred):

    # Predict values for Test dataset
    # y_pred = model.predict(xtest)

    # Print the evaluation metrics for the dataset.
    print(classification_report(y_test, y_pred))

    # Compute and plot the Confusion matrix
    cf_matrix = confusion_matrix(y_test, y_pred)

    categories  = ['Negative','Positive']
    group_names = ['True Neg','False Pos', 'False Neg','True Pos']
    group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten() / np.sum(cf_matrix)]

    labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)

    sns.heatmap(cf_matrix, annot = labels, cmap = 'Blues',fmt = '',
                xticklabels = categories, yticklabels = categories)

    plt.xlabel("Predicted values", fontdict = {'size':14}, labelpad = 10)
    plt.ylabel("Actual values"   , fontdict = {'size':14}, labelpad = 10)
    plt.title ("Confusion Matrix", fontdict = {'size':18}, pad = 20)

# %% [markdown]
# ## Random Forest

# %%
forest = RandomForestClassifier(n_estimators = 1000, random_state = 50)
forest = forest.fit(X_train, y_train)
forest_y_pred = forest.predict(X_test)

forest.score(X_test, y_test)
# Out:
# 0.948274064031703

# %%
modelResult(forest_y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      8905
#            1       0.82      0.36      0.49       684
#
#     accuracy                           0.95      9589
#    macro avg       0.88      0.67      0.73      9589
# weighted avg       0.94      0.95      0.94      9589

# %% [markdown]
# ## LinearSVC

# %%
pca = PCA(n_components=15)

lsvm_X_train = pca.fit_transform(X_train)
lsvm_X_test  = pca.transform(X_test)

SVCmodel = LinearSVC()
SVCmodel.fit(lsvm_X_train, y_train)
lsvm_y_pred = SVCmodel.predict(lsvm_X_test)

SVCmodel.score(lsvm_X_test, y_test)
# Out:
# 0.9320054228803838

# %%
modelResult(lsvm_y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      8905
#            1       0.81      0.06      0.11       684
#
#     accuracy                           0.93      9589
#    macro avg       0.87      0.53      0.54      9589
# weighted avg       0.92      0.93      0.90      9589

# %% [markdown]
# ## svm with rbf
